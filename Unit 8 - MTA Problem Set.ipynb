# %% [markdown]
# 1.Save the Saturday, June 17th, 2017 data to a csv file. You can find it here: http://web.mta.info/developers/turnstile.html and read it in using read_csv. View the head of the dataframe.

# %%
import pandas as pd

MTA = pd.read_csv('MTA_data.csv')

# %% [markdown]
# 2.View the dataframe columns. Is there extra whitespace at the end of any of the column names? Strip all of the whitespace.

# %%
MTA.columns = MTA.columns.str.strip()

# %% [markdown]
# 3.In one line, determine how many rows are in your dataframe and if there are are any null entries.

# %%
MTA.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197209 entries, 0 to 197208
# Data columns (total 11 columns):
# C/A         197209 non-null object
# UNIT        197209 non-null object
# SCP         197209 non-null object
# STATION     197209 non-null object
# LINENAME    197209 non-null object
# DIVISION    197209 non-null object
# DATE        197209 non-null object
# TIME        197209 non-null object
# DESC        197209 non-null object
# ENTRIES     197209 non-null int64
# EXITS       197209 non-null int64
# dtypes: int64(2), object(9)
# memory usage: 16.6+ MB

# %% [markdown]
# 4.In one line, print out the unique STATION names. How many are there? (Hint: use set).

# %%
set(MTA.STATION)
# Out:
# {'1 AV',
#  '103 ST',
#  '103 ST-CORONA',
#  '104 ST',
#  '110 ST',
#  '111 ST',
#  '116 ST',
#  '116 ST-COLUMBIA',
#  '121 ST',
#  '125 ST',
#  '135 ST',
#  '137 ST CITY COL',
#  '138/GRAND CONC',
#  '14 ST',
#  '14 ST-UNION SQ',
#  '145 ST',
#  '149/GRAND CONC',
#  '14TH STREET',
#  '15 ST-PROSPECT',
#  '155 ST',
#  '157 ST',
#  '161/YANKEE STAD',
#  '163 ST-AMSTERDM',
#  '167 ST',
#  '168 ST',
#  '169 ST',
#  '170 ST',
#  '174 ST',
#  '174-175 STS',
#  '175 ST',
#  '176 ST',
#  '18 AV',
#  '18 ST',
#  '181 ST',
#  '182-183 STS',
#  '183 ST',
#  '190 ST',
#  '191 ST',
#  '2 AV',
#  '20 AV',
#  '207 ST',
#  '21 ST',
#  '21 ST-QNSBRIDGE',
#  '215 ST',
#  '219 ST',
#  '225 ST',
#  '23 ST',
#  '231 ST',
#  '233 ST',
#  '238 ST',
#  '25 AV',
#  '25 ST',
#  '28 ST',
#  '3 AV',
#  '3 AV 138 ST',
#  '3 AV-149 ST',
#  '30 AV',
#  '33 ST',
#  '33 ST-RAWSON ST',
#  '34 ST-HERALD SQ',
#  '34 ST-HUDSON YD',
#  '34 ST-PENN STA',
#  '36 AV',
#  '36 ST',
#  '39 AV',
#  '4 AV-9 ST',
#  '40 ST LOWERY ST',
#  '42 ST-BRYANT PK',
#  '42 ST-PORT AUTH',
#  '45 ST',
#  '46 ST',
#  '46 ST BLISS ST',
#  '47-50 STS ROCK',
#  '49 ST',
#  '4AV-9 ST',
#  '5 AV/53 ST',
#  '5 AV/59 ST',
#  '5 AVE',
#  '50 ST',
#  '51 ST',
#  '52 ST',
#  '55 ST',
#  '57 ST',
#  '57 ST-7 AV',
#  '59 ST',
#  '59 ST COLUMBUS',
#  '6 AV',
#  '61 ST WOODSIDE',
#  '63 DR-REGO PARK',
#  '65 ST',
#  '66 ST-LINCOLN',
#  '67 AV',
#  '68ST-HUNTER CO',
#  '69 ST',
#  '7 AV',
#  '71 ST',
#  '72 ST',
#  '72 ST-2 AVE',
#  '74 ST-BROADWAY',
#  '75 AV',
#  '75 ST-ELDERTS',
#  '77 ST',
#  '79 ST',
#  '8 AV',
#  '8 ST-NYU',
#  '80 ST',
#  '81 ST-MUSEUM',
#  '82 ST-JACKSON H',
#  '85 ST-FOREST PK',
#  '86 ST',
#  '86 ST-2 AVE',
#  '88 ST',
#  '9 AV',
#  '90 ST-ELMHURST',
#  '96 ST',
#  '96 ST-2 AVE',
#  '9TH STREET',
#  'ALABAMA AV',
#  'ALLERTON AV',
#  'AQUEDUCT N.COND',
#  'AQUEDUCT RACETR',
#  'ASTOR PL',
#  'ASTORIA BLVD',
#  'ASTORIA DITMARS',
#  'ATL AV-BARCLAY',
#  'ATLANTIC AV',
#  'AVENUE H',
#  'AVENUE I',
#  'AVENUE J',
#  'AVENUE M',
#  'AVENUE N',
#  'AVENUE P',
#  'AVENUE U',
#  'AVENUE X',
#  "B'WAY-LAFAYETTE",
#  'BAY 50 ST',
#  'BAY PKWY',
#  'BAY RIDGE-95 ST',
#  'BAYCHESTER AV',
#  'BEACH 105 ST',
#  'BEACH 25 ST',
#  'BEACH 36 ST',
#  'BEACH 44 ST',
#  'BEACH 60 ST',
#  'BEACH 67 ST',
#  'BEACH 90 ST',
#  'BEACH 98 ST',
#  'BEDFORD AV',
#  'BEDFORD PK BLVD',
#  'BEDFORD-NOSTRAN',
#  'BERGEN ST',
#  'BEVERLEY ROAD',
#  'BEVERLY RD',
#  'BLEECKER ST',
#  'BOROUGH HALL',
#  'BOTANIC GARDEN',
#  'BOWERY',
#  'BOWLING GREEN',
#  'BRIARWOOD',
#  'BRIGHTON BEACH',
#  'BROAD CHANNEL',
#  'BROAD ST',
#  'BROADWAY',
#  'BROADWAY JCT',
#  'BRONX PARK EAST',
#  'BROOK AV',
#  'BROOKLYN BRIDGE',
#  'BUHRE AV',
#  'BURKE AV',
#  'BURNSIDE AV',
#  'BUSHWICK AV',
#  'CANAL ST',
#  'CANARSIE-ROCKAW',
#  'CARROLL ST',
#  'CASTLE HILL AV',
#  'CATHEDRAL PKWY',
#  'CENTRAL AV',
#  'CENTRAL PK N110',
#  'CHAMBERS ST',
#  'CHAUNCEY ST',
#  'CHRISTOPHER ST',
#  'CHURCH AV',
#  'CITY / BUS',
#  'CITY HALL',
#  'CLARK ST',
#  'CLASSON AV',
#  'CLEVELAND ST',
#  'CLINTON-WASH AV',
#  'CONEY IS-STILLW',
#  'CORTELYOU RD',
#  'CORTLANDT ST',
#  'COURT SQ',
#  'COURT SQ-23 ST',
#  'CRESCENT ST',
#  'CROWN HTS-UTICA',
#  'CYPRESS AV',
#  'CYPRESS HILLS',
#  'DEKALB AV',
#  'DELANCEY/ESSEX',
#  'DITMAS AV',
#  'DYCKMAN ST',
#  "E 143/ST MARY'S",
#  'E 149 ST',
#  'E 180 ST',
#  'EAST 105 ST',
#  'EAST BROADWAY',
#  'EASTCHSTER/DYRE',
#  'EASTN PKWY-MUSM',
#  'ELDER AV',
#  'ELMHURST AV',
#  'EUCLID AV',
#  'EXCHANGE PLACE',
#  'FAR ROCKAWAY',
#  'FLATBUSH AV-B.C',
#  'FLUSHING AV',
#  'FLUSHING-MAIN',
#  'FORDHAM RD',
#  'FOREST AVE',
#  'FOREST HILLS 71',
#  'FRANKLIN AV',
#  'FRANKLIN ST',
#  'FREEMAN ST',
#  'FRESH POND RD',
#  'FT HAMILTON PKY',
#  'FULTON ST',
#  'GATES AV',
#  'GRAHAM AV',
#  'GRAND ARMY PLAZ',
#  'GRAND ST',
#  'GRAND-NEWTOWN',
#  'GRANT AV',
#  'GRD CNTRL-42 ST',
#  'GREENPOINT AV',
#  'GROVE STREET',
#  'GUN HILL RD',
#  'HALSEY ST',
#  'HARLEM 148 ST',
#  'HARRISON',
#  'HEWES ST',
#  'HIGH ST',
#  'HOUSTON ST',
#  'HOWARD BCH JFK',
#  'HOYT ST',
#  'HOYT-SCHER',
#  'HUNTERS PT AV',
#  'HUNTS POINT AV',
#  'INTERVALE AV',
#  'INWOOD-207 ST',
#  'JACKSON AV',
#  'JAMAICA 179 ST',
#  'JAMAICA CENTER',
#  'JAMAICA VAN WK',
#  'JAY ST-METROTEC',
#  'JEFFERSON ST',
#  'JFK JAMAICA CT1',
#  'JKSN HT-ROOSVLT',
#  'JOURNAL SQUARE',
#  'JUNCTION BLVD',
#  'JUNIUS ST',
#  'KEW GARDENS',
#  'KINGS HWY',
#  'KINGSBRIDGE RD',
#  'KINGSTON AV',
#  'KINGSTON-THROOP',
#  'KNICKERBOCKER',
#  'KOSCIUSZKO ST',
#  'LACKAWANNA',
#  'LAFAYETTE AV',
#  'LEXINGTON AV/53',
#  'LEXINGTON AV/63',
#  'LIBERTY AV',
#  'LIVONIA AV',
#  'LONGWOOD AV',
#  'LORIMER ST',
#  'MARBLE HILL-225',
#  'MARCY AV',
#  'METROPOLITAN AV',
#  'METS-WILLETS PT',
#  'MIDDLETOWN RD',
#  'MONTROSE AV',
#  'MORGAN AV',
#  'MORISN AV/SNDVW',
#  'MORRIS PARK',
#  'MOSHOLU PKWY',
#  'MT EDEN AV',
#  'MYRTLE AV',
#  'MYRTLE-WILLOUGH',
#  'MYRTLE-WYCKOFF',
#  'NASSAU AV',
#  'NECK RD',
#  'NEPTUNE AV',
#  'NEREID AV',
#  'NEVINS ST',
#  'NEW LOTS',
#  'NEW LOTS AV',
#  'NEW UTRECHT AV',
#  'NEWARK BM BW',
#  'NEWARK C',
#  'NEWARK HM HE',
#  'NEWARK HW BMEBE',
#  'NEWKIRK AV',
#  'NEWKIRK PLAZA',
#  'NORTHERN BLVD',
#  'NORWOOD 205 ST',
#  'NORWOOD AV',
#  'NOSTRAND AV',
#  'OCEAN PKWY',
#  'ORCHARD BEACH',
#  'OZONE PK LEFFRT',
#  'PARK PLACE',
#  'PARKCHESTER',
#  'PARKSIDE AV',
#  'PARSONS BLVD',
#  'PATH NEW WTC',
#  'PATH WTC 2',
#  'PAVONIA/NEWPORT',
#  'PELHAM BAY PARK',
#  'PELHAM PKWY',
#  'PENNSYLVANIA AV',
#  'PRESIDENT ST',
#  'PRINCE ST',
#  'PROSPECT AV',
#  'PROSPECT PARK',
#  'QUEENS PLAZA',
#  'QUEENSBORO PLZ',
#  'RALPH AV',
#  'RECTOR ST',
#  'RIT-MANHATTAN',
#  'RIT-ROOSEVELT',
#  'ROCKAWAY AV',
#  'ROCKAWAY BLVD',
#  'ROCKAWAY PARK B',
#  'ROOSEVELT ISLND',
#  'SARATOGA AV',
#  'SENECA AVE',
#  'SHEEPSHEAD BAY',
#  'SHEPHERD AV',
#  'SIMPSON ST',
#  'SMITH-9 ST',
#  'SOUTH FERRY',
#  'SPRING ST',
#  'ST LAWRENCE AV',
#  'ST. GEORGE',
#  'STEINWAY ST',
#  'STERLING ST',
#  'SUTPHIN BLVD',
#  'SUTPHIN-ARCHER',
#  'SUTTER AV',
#  'SUTTER AV-RUTLD',
#  'THIRTY ST',
#  'THIRTY THIRD ST',
#  'TIMES SQ-42 ST',
#  'TOMPKINSVILLE',
#  'TREMONT AV',
#  'TWENTY THIRD ST',
#  'UNION ST',
#  'UTICA AV',
#  'V.CORTLANDT PK',
#  'VAN SICLEN AV',
#  'VAN SICLEN AVE',
#  'VERNON-JACKSON',
#  'W 4 ST-WASH SQ',
#  'W 8 ST-AQUARIUM',
#  'WAKEFIELD/241',
#  'WALL ST',
#  'WEST FARMS SQ',
#  'WESTCHESTER SQ',
#  'WHITEHALL S-FRY',
#  'WHITLOCK AV',
#  'WILSON AV',
#  'WINTHROP ST',
#  'WOODHAVEN BLVD',
#  'WOODLAWN',
#  'WORLD TRADE CTR',
#  'YORK ST',
#  'ZEREGA AV'}

# %%
print(len(set(MTA.STATION)))
# Out:
# 376

# %% [markdown]
# 5.Okay, so we understand what station represents. But what the heck are C/A, UNIT, and SCP? Keep in mind that in the larger stations, you might have multiple areas within one station that look like this:
#
# <img src="image.jpg" style="width: 300px;"/>
#
# Further complicating things, there are a few station names like 14TH ST that refer to more than one station location along that street.
#
# This data set is not very well documented. Welcome to the joys of real world data science!!!
#
# Read the following two links carefully to see other people's confusion and what information they have been able to gather:
#
# https://groups.google.com/forum/#!topic/mtadeveloperresources/AMVx2WUY9iI
#
# https://groups.google.com/forum/#!searchin/mtadeveloperresources/%22remote$20unit%22%7Csort:relevance/mtadeveloperresources/z8l3ZU9cY6Y/OFlHGkFAimQJ
#
# What did Patrick O'Hara and Katie Toth have to say?

# %%
Katie: Every time a person walks in the data says "REGULAR".  "LOGON" and "DOORCLOSE"
Patrick: There are multiple names for one station (some names are dated)-there might be two names for one station
# Out:
#   File "<ipython-input-6-304668f74f6c>", line 1
#     Katie: Every time a person walks in the data says "REGULAR".  "LOGON" and "DOORCLOSE"
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# 6.To simplify our calculations right now, let's only look at ridership on Monday, June 12th, 2017. In one line, create a dataset called monday that just includes the dates listed as 06/12/2017.
#
# Then, use the command "monday = monday.reset_index(drop=True)" to reset the index.

# %%
monday = MTA[MTA.DATE == '06/12/2017']
monday = monday.reset_index(drop=True)

# %% [markdown]
# 7.Create a dictionary called monday_dict mapping the tuple (C/A, UNIT,SCP, STATION) to a list of tuples containing (TIME,EXITS).
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') in your dictionary should give the value:
#
# [('00:00:00', 2104727),
#  ('04:00:00', 2104729),
#  ('08:00:00', 2104813),
#  ('12:00:00', 2105024),
#  ('16:00:00', 2105081),
#  ('20:00:00', 2105134)]

# %%
monday_dict={}
for i in range(len(monday.index)):
    mytuple=(monday['C/A'][i],monday['UNIT'][i],monday['SCP'][i],monday['STATION'][i])
    if mytuple not in monday_dict:
        monday_dict[mytuple]=[(monday['TIME'][i],monday['EXITS'][i])]
    else:
        monday_dict[mytuple].append((monday['TIME'][i],monday['EXITS'][i]))

# %% [markdown]
# 8.Note: as you get more comfortable with pandas, you will rely more on built-in pandas capabilities and less on creating dictionaries from scratch. For example, run the following lines of code to verify that this dataframe gives you the same info that you got in Exercise 7.

# %%
x=monday.groupby(['C/A', 'UNIT', 'SCP', 'STATION']).groups #the keys are the station pairs and the values are the row indices
flds = ['TIME','EXITS'] #we want to make values out of the remaining columns
monday_exits = {key: monday.loc[val,flds] for key, val in x.items()}
monday_exits[('A002', 'R051', '02-00-00','59 ST')]
# Out:
#        TIME    EXITS
# 0  00:00:00  2104727
# 1  04:00:00  2104729
# 2  08:00:00  2104813
# 3  12:00:00  2105024
# 4  16:00:00  2105081
# 5  20:00:00  2105134

# %% [markdown]
# 9.What the heck do these exit numbers represent? We can assume that they represent some sort of counter on the turnstile. We can subtract the exits at t=20 minus t=0 to figure out how many riders exited this turnstile between midnight and 8 pm.
#
# Can we calculate 20 - 0 for all of the stations? No! Unfortunately, the time increments aren't standardized. Many of the times are listed in 4 hour intervals of midnight, 4 am, 8 am, etc but not all. Make a frequency chart of the times for the monday dataframe from Exercise 6.

# %%
monday.TIME.value_counts()

# %% [markdown]
# 10.Use your monday_dict from Exercise 7 to create a dictionary called monday_dict_diff that maps (C/A, UNIT, SCP, STATION) to the differences in exits between two consective times in order to see how many people exited through a turnstile within a given time interval.
#
# For example, the key ('A002', 'R051', '02-00-00','59 ST') should map to:
#
# [('04:00:00', 2),
#  ('08:00:00', 84),
#  ('12:00:00', 211),
#  ('16:00:00', 57),
#  ('20:00:00', 53)]

# %%
monday_dict_diff = {}

for key,value in monday_dict.items():
    for i in range(1,len(value)):
        if key not in monday_dict_diff:
            monday_dict_diff[key] = [(value[i][0],value[i][1]-value[i-1][1])]
        else:
            monday_dict_diff[key].append((value[i][0],value[i][1]-value[i-1][1]))
print(monday_dict_diff[('A002', 'R051', '02-00-00','59 ST')])

# %% [markdown]
# 11.Once again, note that pandas can do the above calculation for you. If you used the monday_exits dataframe from Exercise 8, run the following code to verify that you obtain what you just got in Exercise 10. It may take a bit longer to run.

# %%
monday_diff = {}

for turnstile, slice_df in monday_exits.items():
    diff = slice_df['EXITS'].diff().values #calculates the exit difference between each entry
    monday_diff[turnstile] = pd.Series(diff, index=slice_df['TIME'].values) #maps turnstile to (time, exit difference) pairs
    for i,(key, val) in enumerate(monday_diff[turnstile].items()):
        try: #need a try because you'll get an error for NAN difference values since there is one less difference than the number of times
            monday_exits[turnstile].at[i,'EXITS'] = val
        except:
            continue
    monday_exits[turnstile] = monday_exits[turnstile].drop(0)    #drop the first time because you only calculate differences after the second time.                   
    
monday_exits[('A002', 'R051', '02-00-00', '59 ST')]

# %% [markdown]
# 12.Find how many people in total passed through a given turnstile between the hours given for 06/12/2017. For example, if a turnstile is on increments of 0,4,8,...,20, then you want to find out how many total people passed through between midnight and 8 pm. Create a dictionary called total_turnstile that maps (C/A,UNIT,SCP,STATION) to total Monday ridership. Use your dictionary from Exercise 10.
#
# Hint: the key ('A002', 'R051', '02-00-00', '59 ST') should map to 407 total riders.

# %%
monday_diff = {}

for turnstile, slice_df in monday_exits.items():
    total_turnstile = {}
for key, value in monday_dict_diff.items():
    for i in range(0, len(value)):
        total_turnstile[key]=total_turnstile.get(key, 0)+value[i][1]

print(total_turnstile[('A002', 'R051', '02-00-00', '59 ST')])

# %% [markdown]
# 13.Use your work in Exercise 12 to create a dictionary called total_riders that maps the (C/A, UNIT, STATION) location to all riders that passed through ALL of the turnstiles in that area on Monday.
#
# Hint 1: use the get command
#
# Hint 2: ('A002', 'R051', '59 ST') should have 6704 total riders.

# %%
#insert 13
#for reference: 
#C/A = Control Area (A002)
#UNIT = Remote Unit for a station (R051)
#SCP = Subunit Channel Position represents an specific address for a device (02-00-00)

total_riders = {}
for key, value in total_turnstile.items():
    new_key = (key[0], key[1], key[3])
    total_riders[new_key]=total_riders.get(new_key, 0)+value
print(total_riders[ ('A002', 'R051', '59 ST')])

# %% [markdown]
# 14.Create a list of tuples called tuple_list using your total_riders dictionary so that you can sort the list in decending order to see busiest stations. Hint: the busiest area should be the PATH World Trade Center station.

# %%
tuple_list=[]
for key, value in total_riders.items():
    mytuple=(value, key[2])
    tuple_list.append(mytuple)
tuple_list.sort(reverse=True)
print(tuple_list)

# %% [markdown]
# 15.Look at the three smallest riderships in your above tuple list. Do they make sense? What about your data caused negative numbers? Welcome to the world of buggy real world data! Remove these three items from your tuple list.

# %%
print(tuple_list[-1], tuple_list[-2], tuple_list[-3], tuple_list[-4])
#They do not make sense, they are negative. Because data is weird. 
del tuple_list[-1]
del tuple_list[-1]
del tuple_list[-1]
print(tuple_list)

# %% [markdown]
# 16.Create a barchart for the number of riders. You don't need to keep track of the names of each station, as that would get really messy to plot. Instead, you can just use a list comprehension to save the rider numbers to the y-values and give the stations the numbers 0,1,2,3,... for the x-values. You can use the following piece of code. Remember to add in axis labels and a title.
#
# x = range(len(tuple_list))
#
# y = [tuple_list[i][0] for i in range(len(tuple_list))]
#
# plt.bar(x,y)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
x = range(len(tuple_list))
y = [tuple_list[i][0] for i in range(len(tuple_list))]
plt.bar(x,y)
plt.xlabel("Station Number")
plt.ylabel("Number of Riders")
plt.title("Ridership by Station")

# %% [markdown]
# 17.Perhaps we don't care about total ridership in a 24 period. Perhaps we only care about the morning commute. Let's assume that the majority of people arrive at their work location subway exit between 8 and 9 am.
#
# Go back up to your frequency chart in Exercise 9. Note that the most common morning commutes would be gained from subtracting 9 am - 5 am and 10 am - 6 am and 11 am - 7 am and 12pm - 8am, for the stations that are broken down by those specific four hour intervals.
#
# As a dirty way to consider only the stations that are on these time intervals, save just the rows in your original monday dataframe that contain the TIME strings '05:00:00', '06:00:00',..., '12:00:00'. Remember you can do this by using OR statements using the "|" symbol and remembering parenthesis. Call this new dataframe "morning". Be sure to reset its index.

# %%
morning=monday[(monday.TIME =="05:00:00")|(monday.TIME == "06:00:00")|(monday.TIME =="07:00:00")|(monday.TIME == "08:00:00")|(monday.TIME == "09:00:00")|(monday.TIME == "10:00:00")|(monday.TIME == "11:00:00")|(monday.TIME == "12:00:00")]
morning = morning.reset_index(drop=True)
morning

# %% [markdown]
# 18.Now create a morning_dict by repeating your work in Exercise 7 on this morning dataframe. The dictionary should map the tuple (C/A, UNIT, SCP,STATION) to an inner dictionary containing {TIME: EXITS} for all Monday rides.
#
# Hint: ('A002', 'R051', '02-00-00','59 ST') should map to {'08:00:00': 2104813, '12:00:00': 2105024}.

# %%
morning_dict={}
for i in range(len(morning.index)):
    mytuple= (morning['C/A'][i], morning.UNIT[i], morning.SCP[i], morning.STATION[i])
    if mytuple not in morning_dict.keys():
        morning_dict[mytuple]={morning.TIME[i]:morning.EXITS[i]}
    else:
        morning_dict[mytuple][morning.TIME[i]]=morning.EXITS[i]
morning_dict[('A002', 'R051', '02-00-00','59 ST')]

# %% [markdown]
# 19.We're almost ready to subtract the two consecutive times for each station to get the morning commutes. That is, if there are exactly two times for each station. Find which stations keys in your dictionary above do not contain exactly two times and delete them from the morning dictionary.
#
# How many keys are left in your morning_dict? There should be 4293.

# %%
bad_key = []
for key, value in morning_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in morning_dict:
        del morning_dict[key]
print(len(morning_dict))

# %% [markdown]
# 20.Create a dictionary called morning_differences where (C/A, UNIT, STATION) maps to an inner dictionary containing {SCP: Morning Exit Differences}.
#
# For example, ('A002', 'R051', '59 ST') should map to:
#
# {'02-00-00': 211,
#  '02-00-01': 128,
#  '02-03-00': 654,
#  '02-03-01': 630,
#  '02-03-02': 533,
#  '02-03-03': 401,
#  '02-03-04': 186,
#  '02-03-05': 49,
#  '02-03-06': 8,
#  '02-05-00': 0,
#  '02-05-01': 0,
#  '02-06-00': 4}

# %%
morning_differences = {}
for turnstile,times in morning_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, exit in times.items():
        count = exit - count
    if mytuple not in morning_differences:
        morning_differences[mytuple]={turnstile[2]:count}
    else:
        morning_differences[mytuple][turnstile[2]]=count
print(morning_differences[('A002', 'R051', '59 ST') ])

# %% [markdown]
# 21.Create a dictionary called total_morning_diff that maps each (C/A, Unit, Station) location to the total morning riders passing through ALL of the turnstiles in that area.
#
# Hint 1: see your work in Exercise 13.
#
# Hint 2: ('A002', 'R051','59 ST') should have 2804 morning commuter exits.

# %%
total_morning_diff = {}
for key, value in morning_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_morning_diff[key] = count
print(total_morning_diff[('A002', 'R051', '59 ST')])

# %% [markdown]
# 22.Create a list of sorted tuples to see the most popular morning exits.
#
# Hint:  ('R238', 'R046', 'GRD CNTRL-42 ST') should be the highest with 17,300 morning exits.

# %%
list_of_tuples = []
for key, value in total_morning_diff.items():
    list_of_tuples.append((value, key))
list_of_tuples.sort(reverse=True)
print(list_of_tuples)

# %% [markdown]
# 23.We notice that the ('R204', 'R043', 'WALL ST') stop is pretty high on the Monday morning list. How can we tell if this exit is more of a commuter or tourist exit? Maybe we'll see if the total number of people is higher on a weekday than a weekend. Go back to the original df dataframe. Save only the items that contain ('R204', 'R043', 'WALL ST') to a dataframe called wallstreet and create a list of tuples where the first entry is the date and the second entry is the total ridership.
#
# Hint: there should be 9936 riders on 06/15/2017.

# %%
wallstreet = MTA[(MTA['C/A'] == 'R204') 
                & (MTA['UNIT'] == 'R043')
                & (MTA['STATION'] == 'WALL ST')]
wallstreet = wallstreet.reset_index(drop=True)

wall_dict={}
for i in range(len(wallstreet.index)):
    mytuple = wallstreet.DATE[i]
    if mytuple not in wall_dict.keys():
        wall_dict[mytuple]={wallstreet.SCP[i]:{wallstreet.TIME[i]:wallstreet.EXITS[i]}}
    if wallstreet.SCP[i] not in wall_dict[mytuple].keys():
         wall_dict[mytuple][wallstreet.SCP[i]]={wallstreet.TIME[i]:wallstreet.EXITS[i]}
    else:
        wall_dict[mytuple][wallstreet.SCP[i]][wallstreet.TIME[i]]=wallstreet.EXITS[i]
#print(wall_dict['06/12/2017'])

wall_exits = {}
for date,turnstile_info in wall_dict.items():
    for turnstile,exit_info in turnstile_info.items():
        start = wall_dict[date][turnstile][sorted(exit_info)[0]]
        end = wall_dict[date][turnstile][sorted(exit_info)[-1]]
        if date not in wall_exits.keys():
            wall_exits[date]={}
        wall_exits[date][turnstile]=end-start
print(wall_dict['06/12/2017'])

tuple_list = []
for date, turnstiles in wall_exits.items():
    count = 0 
    for exit in turnstiles.values():
        count = count + exit
    tuple_list.append((date, count))
tuple_list.sort()
tuple_list

# %% [markdown]
# 24.Plot the list of tuples you made where date is the x-axis and ridership is the y-axis for this wall street station.
#
# Hint: you'll first need to use datetime to convert the dates to datetime format.

# %%
print(tuple_list)
# %matplotlib inline
from datetime import datetime
riders = []
dates = []
for date,rider in tuple_list:
    dates.append(datetime.strptime(date,'%m/%d/%Y'))
    riders.append(rider)
plt.plot(dates,riders, '.');

# %% [markdown]
# 25.Now use datetime to convert the dates to "Mon", "Tues", etc and print the days of the week with corresponding ridership. Is this a commuter stop or a tourist stop?

# %%
for date,rider in tuple_list:
    time_info = datetime.strptime(date,'%m/%d/%Y')
    print (time_info.strftime("%a"))

# %%
#Monday evening

mon_evening=monday[(monday.TIME =="16:00:00")|(monday.TIME == "17:00:00")|(monday.TIME =="18:00:00")|(monday.TIME == "19:00:00")|(monday.TIME == "20:00:00")]
mon_evening = mon_evening.reset_index(drop=True)

mon_evening_dict={}
for i in range(len(mon_evening.index)):
    mytuple= (mon_evening['C/A'][i], mon_evening.UNIT[i], mon_evening.SCP[i], mon_evening.STATION[i])
    if mytuple not in mon_evening_dict.keys():
        mon_evening_dict[mytuple]={mon_evening.TIME[i]:mon_evening.ENTRIES[i]}
    else:
        mon_evening_dict[mytuple][mon_evening.TIME[i]]=mon_evening.ENTRIES[i]

bad_key = []
for key, value in mon_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in mon_evening_dict:
        del mon_evening_dict[key]

mon_evening_differences = {}
for turnstile,times in mon_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in mon_evening_differences:
        mon_evening_differences[mytuple]={turnstile[2]:count}
    else:
        mon_evening_differences[mytuple][turnstile[2]]=count

total_mon_evening_diff = {}
for key, value in mon_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_mon_evening_diff[key] = count
    
mon_evening_passengers = []
for key, value in total_mon_evening_diff.items():
    mon_evening_passengers.append((value, key))
mon_evening_passengers.sort(reverse=True)
for line in mon_evening_passengers:
    print(line)
# Out:
# (19321, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (18031, ('N500', 'R020', '47-50 STS ROCK'))
# (15755, ('N051', 'R084', '59 ST COLUMBUS'))
# (14007, ('N501', 'R020', '47-50 STS ROCK'))
# (13750, ('N306', 'R017', 'LEXINGTON AV/53'))
# (12954, ('N505', 'R022', '34 ST-HERALD SQ'))
# (11510, ('N504', 'R021', '42 ST-BRYANT PK'))
# (10509, ('R116', 'R030', 'CHAMBERS ST'))
# (10032, ('R250', 'R179', '86 ST'))
# (9884, ('N092', 'R029', 'CHAMBERS ST'))
# (9419, ('N506', 'R022', '34 ST-HERALD SQ'))
# (9276, ('N520', 'R240', 'GRAND ST'))
# (8942, ('N103', 'R127', 'JAY ST-METROTEC'))
# (8914, ('R533', 'R055', 'FLUSHING-MAIN'))
# (8908, ('R200A', 'R041', 'BOWLING GREEN'))
# (8717, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (8570, ('A022', 'R022', '34 ST-HERALD SQ'))
# (8469, ('A025', 'R023', '34 ST-HERALD SQ'))
# (8328, ('A010', 'R080', '57 ST-7 AV'))
# (8322, ('N502', 'R021', '42 ST-BRYANT PK'))
# (8284, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (7941, ('N049', 'R084', '59 ST COLUMBUS'))
# (7803, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (7747, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (7671, ('N094', 'R029', 'WORLD TRADE CTR'))
# (7658, ('R501', 'R054', '5 AVE'))
# (6991, ('R154', 'R116', '50 ST'))
# (6964, ('N507', 'R023', '34 ST-HERALD SQ'))
# (6926, ('N102', 'R127', 'JAY ST-METROTEC'))
# (6837, ('A030', 'R083', '23 ST'))
# (6836, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (6792, ('N509', 'R203', '23 ST'))
# (6754, ('R244A', 'R050', '59 ST'))
# (6595, ('N091', 'R029', 'CHAMBERS ST'))
# (6595, ('N089', 'R139', 'CANAL ST'))
# (6364, ('R155', 'R116', '50 ST'))
# (6315, ('R182', 'R035', '168 ST'))
# (6246, ('N026', 'R102', '125 ST'))
# (6213, ('H009', 'R235', 'BEDFORD AV'))
# (6124, ('A002', 'R051', '59 ST'))
# (6054, ('C008', 'R099', 'DEKALB AV'))
# (5975, ('R602', 'R108', 'BOROUGH HALL'))
# (5891, ('R110', 'R027', 'WALL ST'))
# (5799, ('R158', 'R084', '59 ST COLUMBUS'))
# (5776, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (5690, ('N501A', 'R020', '47-50 STS ROCK'))
# (5686, ('R245A', 'R051', '59 ST'))
# (5596, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (5469, ('N606', 'R025', 'JAMAICA CENTER'))
# (5438, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (5433, ('R141', 'R031', '34 ST-PENN STA'))
# (5367, ('N503', 'R021', '42 ST-BRYANT PK'))
# (5324, ('R242', 'R049', '51 ST'))
# (5316, ('R217A', 'R194', 'BLEECKER ST'))
# (5176, ('N400A', 'R359', 'COURT SQ'))
# (5143, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (5122, ('R201', 'R041', 'BOWLING GREEN'))
# (5107, ('N508', 'R453', '23 ST'))
# (5063, ('A015', 'R081', '49 ST'))
# (5018, ('R111', 'R027', 'WALL ST'))
# (5007, ('R244', 'R050', '59 ST'))
# (4989, ('S101A', 'R070', 'ST. GEORGE'))
# (4939, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (4918, ('R249', 'R179', '86 ST'))
# (4906, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (4893, ('R243', 'R049', '51 ST'))
# (4840, ('A011', 'R080', '57 ST-7 AV'))
# (4678, ('A041', 'R086', 'PRINCE ST'))
# (4591, ('R550', 'R072', '34 ST-HUDSON YD'))
# (4544, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (4461, ('N076', 'R111', '23 ST'))
# (4432, ('A031', 'R083', '23 ST'))
# (4399, ('N072', 'R012', '34 ST-PENN STA'))
# (4314, ('N086', 'R282', 'SPRING ST'))
# (4284, ('N057', 'R188', '50 ST'))
# (4281, ('N067', 'R012', '34 ST-PENN STA'))
# (4192, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (4139, ('R127', 'R105', '14 ST'))
# (4132, ('R516', 'R291', '33 ST-RAWSON ST'))
# (4048, ('N305', 'R017', 'LEXINGTON AV/53'))
# (4032, ('N068', 'R012', '34 ST-PENN STA'))
# (3970, ('A038', 'R085', '8 ST-NYU'))
# (3904, ('N090', 'R139', 'CANAL ST'))
# (3820, ('N108', 'R217', 'HOYT-SCHER'))
# (3765, ('R215', 'R322', 'SPRING ST'))
# (3761, ('R526', 'R096', '82 ST-JACKSON H'))
# (3684, ('N020', 'R101', '145 ST'))
# (3683, ('N063', 'R011', '42 ST-PORT AUTH'))
# (3677, ('A047', 'R087', 'CITY HALL'))
# (3586, ('H008', 'R248', '1 AV'))
# (3516, ('A027', 'R082', '28 ST'))
# (3515, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (3508, ('N043', 'R186', '86 ST'))
# (3500, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (3468, ('R601A', 'R108', 'BOROUGH HALL'))
# (3412, ('N046', 'R281', '72 ST'))
# (3342, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3342, ('N601', 'R319', 'LEXINGTON AV/63'))
# (3327, ('R528', 'R097', 'JUNCTION BLVD'))
# (3277, ('N070', 'R012', '34 ST-PENN STA'))
# (3188, ('A013', 'R081', '49 ST'))
# (3146, ('H007', 'R248', '1 AV'))
# (3091, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (3051, ('R129', 'R321', '18 ST'))
# (3003, ('N307', 'R359', 'COURT SQ-23 ST'))
# (2952, ('R534', 'R055', 'FLUSHING-MAIN'))
# (2947, ('R604', 'R108', 'BOROUGH HALL'))
# (2939, ('R112', 'R027', 'WALL ST'))
# (2885, ('N056', 'R188', '50 ST'))
# (2878, ('R527', 'R122', '90 ST-ELMHURST'))
# (2876, ('A069', 'R044', 'CHAMBERS ST'))
# (2859, ('N062', 'R011', '42 ST-PORT AUTH'))
# (2830, ('N069', 'R013', '34 ST-PENN STA'))
# (2817, ('R529', 'R208', '103 ST-CORONA'))
# (2754, ('N330', 'R202', '63 DR-REGO PARK'))
# (2720, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (2686, ('R112A', 'R027', 'WALL ST'))
# (2677, ('N511', 'R163', '14 ST'))
# (2661, ('N405', 'R239', 'GREENPOINT AV'))
# (2629, ('R183', 'R260', '181 ST'))
# (2578, ('B029', 'R172', 'BRIGHTON BEACH'))
# (2548, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2544, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (2543, ('N523', 'R300', '2 AV'))
# (2533, ('C012', 'R258', '4AV-9 ST'))
# (2491, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (2486, ('A029', 'R082', '28 ST'))
# (2460, ('R289', 'R119', 'FORDHAM RD'))
# (2390, ('N528', 'R257', 'EAST BROADWAY'))
# (2369, ('R202', 'R042', 'BOWLING GREEN'))
# (2306, ('R518', 'R261', '40 ST LOWERY ST'))
# (2287, ('R515', 'R095', 'ASTORIA DITMARS'))
# (2261, ('R306', 'R207', '135 ST'))
# (2249, ('R606', 'R225', 'HOYT ST'))
# (2248, ('R137', 'R031', '34 ST-PENN STA'))
# (2239, ('N512', 'R163', '14 ST'))
# (2214, ('R103', 'R304', 'RECTOR ST'))
# (2208, ('N075', 'R111', '23 ST'))
# (2199, ('R128', 'R105', '14 ST'))
# (2189, ('R261', 'R205', '149/GRAND CONC'))
# (2176, ('N071', 'R013', '34 ST-PENN STA'))
# (2143, ('N408A', 'R256', 'NASSAU AV'))
# (2140, ('R608', 'R056', 'NEVINS ST'))
# (2128, ('R301', 'R323', 'CENTRAL PK N110'))
# (2114, ('N039', 'R251', '96 ST'))
# (2112, ('N100', 'R252', 'HIGH ST'))
# (2110, ('R513', 'R093', '30 AV'))
# (2099, ('R310', 'R053', '3 AV-149 ST'))
# (2084, ('R115', 'R029', 'PARK PLACE'))
# (2081, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (2076, ('N010', 'R126', '175 ST'))
# (2072, ('R125', 'R189', 'CHRISTOPHER ST'))
# (2068, ('B016', 'R098', 'CHURCH AV'))
# (2066, ('A071', 'R044', 'CHAMBERS ST'))
# (2029, ('N077', 'R111', '23 ST'))
# (2025, ('N116', 'R198', 'NOSTRAND AV'))
# (2023, ('H019', 'R294', 'MORGAN AV'))
# (2006, ('R174', 'R034', '125 ST'))
# (2006, ('A016', 'R081', '49 ST'))
# (2003, ('N315', 'R238', 'STEINWAY ST'))
# (1993, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (1989, ('N535', 'R220', 'CARROLL ST'))
# (1952, ('R287', 'R244', 'BURNSIDE AV'))
# (1945, ('R508', 'R346', 'COURT SQ'))
# (1934, ('R102', 'R304', 'RECTOR ST'))
# (1928, ('N325A', 'R218', 'ELMHURST AV'))
# (1920, ('N087', 'R282', 'SPRING ST'))
# (1910, ('R512', 'R092', 'BROADWAY'))
# (1888, ('A014', 'R081', '49 ST'))
# (1862, ('R194', 'R040', '231 ST'))
# (1860, ('A054', 'R227', 'RECTOR ST'))
# (1849, ('N124', 'R103', 'BROADWAY JCT'))
# (1845, ('B024', 'R211', 'KINGS HWY'))
# (1800, ('R311', 'R053', '3 AV-149 ST'))
# (1785, ('H006', 'R330', '3 AV'))
# (1782, ('C025', 'R215', '86 ST'))
# (1780, ('N521', 'R300', '2 AV'))
# (1766, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1753, ('N529', 'R257', 'EAST BROADWAY'))
# (1751, ('H022', 'R279', 'JEFFERSON ST'))
# (1750, ('N025', 'R102', '125 ST'))
# (1746, ('N510', 'R163', '14 ST'))
# (1744, ('R504', 'R276', 'VERNON-JACKSON'))
# (1740, ('A042', 'R086', 'PRINCE ST'))
# (1732, ('C019', 'R232', '45 ST'))
# (1728, ('R514', 'R094', 'ASTORIA BLVD'))
# (1703, ('N117', 'R198', 'NOSTRAND AV'))
# (1678, ('R245', 'R051', '59 ST'))
# (1666, ('N073', 'R013', '34 ST-PENN STA'))
# (1663, ('R600', 'R224', 'CLARK ST'))
# (1649, ('R283', 'R221', '167 ST'))
# (1639, ('R519', 'R223', '46 ST BLISS ST'))
# (1621, ('N422', 'R318', 'FULTON ST'))
# (1609, ('R284', 'R243', '170 ST'))
# (1609, ('R185', 'R274', '191 ST'))
# (1603, ('N128', 'R200', 'EUCLID AV'))
# (1599, ('C021', 'R212', '59 ST'))
# (1594, ('R530', 'R310', '111 ST'))
# (1579, ('N217', 'R112', 'FORDHAM RD'))
# (1570, ('B031', 'R172', 'BRIGHTON BEACH'))
# (1550, ('R420', 'R107', 'WESTCHESTER SQ'))
# (1526, ('R511', 'R091', '36 AV'))
# (1505, ('N012', 'R035', '168 ST'))
# (1503, ('N013', 'R035', '168 ST'))
# (1498, ('R139', 'R031', '34 ST-PENN STA'))
# (1493, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1481, ('R254', 'R181', '110 ST'))
# (1477, ('R188', 'R037', '207 ST'))
# (1453, ('R186', 'R036', 'DYCKMAN ST'))
# (1452, ('H017', 'R265', 'MONTROSE AV'))
# (1441, ('A039', 'R085', '8 ST-NYU'))
# (1422, ('A064', 'R311', 'BOWERY'))
# (1410, ('B022', 'R229', 'AVENUE M'))
# (1407, ('N343', 'R019', 'JAMAICA 179 ST'))
# (1391, ('N536', 'R270', 'SMITH-9 ST'))
# (1389, ('H013', 'R249', 'GRAHAM AV'))
# (1383, ('B021', 'R228', 'AVENUE J'))
# (1382, ('R517', 'R291', '33 ST-RAWSON ST'))
# (1380, ('H015', 'R250', 'GRAND ST'))
# (1370, ('A055', 'R227', 'RECTOR ST'))
# (1367, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1356, ('N546', 'R204', 'CHURCH AV'))
# (1354, ('R609', 'R056', 'NEVINS ST'))
# (1346, ('N537', 'R258', '4 AV-9 ST'))
# (1335, ('N207', 'R104', '167 ST'))
# (1334, ('R135', 'R031', '34 ST-PENN STA'))
# (1325, ('C022', 'R212', '59 ST'))
# (1278, ('R294', 'R052', 'WOODLAWN'))
# (1275, ('N314', 'R238', 'STEINWAY ST'))
# (1255, ('N513', 'R163', '14 ST'))
# (1251, ('N040', 'R251', '96 ST'))
# (1237, ('R307', 'R207', '135 ST'))
# (1233, ('R178', 'R273', '145 ST'))
# (1231, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1228, ('N019', 'R101', '145 ST'))
# (1221, ('N101', 'R252', 'HIGH ST'))
# (1217, ('R197', 'R117', 'V.CORTLANDT PK'))
# (1212, ('B023', 'R211', 'KINGS HWY'))
# (1208, ('H023', 'R236', 'DEKALB AV'))
# (1190, ('R503', 'R276', 'VERNON-JACKSON'))
# (1166, ('R192', 'R039', 'MARBLE HILL-225'))
# (1140, ('R286', 'R309', '176 ST'))
# (1133, ('R253', 'R181', '110 ST'))
# (1119, ('N196', 'R285', 'FAR ROCKAWAY'))
# (1111, ('N218', 'R112', 'FORDHAM RD'))
# (1102, ('R605', 'R456', 'HOYT ST'))
# (1097, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (1097, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (1095, ('R260', 'R205', '149/GRAND CONC'))
# (1090, ('E004', 'R234', '50 ST'))
# (1089, ('B013', 'R196', 'PROSPECT PARK'))
# (1078, ('N607', 'R025', 'JAMAICA CENTER'))
# (1056, ('R242A', 'R049', '51 ST'))
# (1046, ('R285', 'R308', 'MT EDEN AV'))
# (1042, ('R629', 'R065', 'ROCKAWAY AV'))
# (1031, ('C024', 'R214', '77 ST'))
# (999, ('N549', 'R242', '18 AV'))
# (998, ('R622', 'R123', 'FRANKLIN AV'))
# (997, ('H028', 'R266', 'HALSEY ST'))
# (990, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (986, ('R624', 'R124', 'KINGSTON AV'))
# (985, ('R510', 'R090', '39 AV'))
# (978, ('E012', 'R372', '18 AV'))
# (973, ('N419', 'R287', 'CLASSON AV'))
# (967, ('B018', 'R184', 'CORTELYOU RD'))
# (960, ('R520', 'R223', '46 ST BLISS ST'))
# (952, ('N342', 'R019', 'JAMAICA 179 ST'))
# (944, ('N534', 'R220', 'CARROLL ST'))
# (943, ('R634', 'R069', 'NEW LOTS AV'))
# (936, ('R623', 'R061', 'NOSTRAND AV'))
# (936, ('C010', 'R231', 'UNION ST'))
# (933, ('R259', 'R307', '138/GRAND CONC'))
# (926, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (922, ('R418', 'R106', 'CASTLE HILL AV'))
# (916, ('N340A', 'R115', '169 ST'))
# (915, ('B024A', 'R211', 'KINGS HWY'))
# (914, ('R288', 'R275', '183 ST'))
# (911, ('C016', 'R278', '25 ST'))
# (904, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (902, ('N339A', 'R114', 'PARSONS BLVD'))
# (897, ('R636', 'R209', 'STERLING ST'))
# (896, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (881, ('R525', 'R018', '74 ST-BROADWAY'))
# (874, ('N119', 'R199', 'KINGSTON-THROOP'))
# (873, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (859, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (839, ('C004', 'R089', 'JAY ST-METROTEC'))
# (837, ('C003', 'R089', 'JAY ST-METROTEC'))
# (828, ('N191', 'R335', 'BEACH 67 ST'))
# (819, ('R628', 'R064', 'SARATOGA AV'))
# (796, ('N011', 'R126', '175 ST'))
# (792, ('B015', 'R098', 'CHURCH AV'))
# (785, ('B012', 'R196', 'PROSPECT PARK'))
# (779, ('R130', 'R321', '18 ST'))
# (772, ('N331', 'R219', '67 AV'))
# (767, ('N215', 'R237', '182-183 STS'))
# (753, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (752, ('H005', 'R330', '3 AV'))
# (746, ('N330C', 'R202', '63 DR-REGO PARK'))
# (744, ('N129', 'R382', 'GRANT AV'))
# (744, ('N006A', 'R280', '190 ST'))
# (736, ('R635', 'R277', 'PRESIDENT ST'))
# (722, ('C001', 'R108', 'BOROUGH HALL'))
# (716, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (715, ('H032', 'R295', 'WILSON AV'))
# (695, ('E011', 'R371', '79 ST'))
# (688, ('E013', 'R373', '20 AV'))
# (684, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (683, ('B032', 'R264', 'OCEAN PKWY'))
# (677, ('E005', 'R247', '55 ST'))
# (663, ('E009', 'R370', '71 ST'))
# (658, ('R728', 'R226', 'GUN HILL RD'))
# (658, ('R309', 'R345', 'HARLEM 148 ST'))
# (649, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (643, ('R177', 'R273', '145 ST'))
# (630, ('N210', 'R253', '174-175 STS'))
# (627, ('R308', 'R344', '145 ST'))
# (617, ('R126', 'R189', 'CHRISTOPHER ST'))
# (613, ('B026', 'R230', 'NECK RD'))
# (596, ('N340', 'R115', '169 ST'))
# (588, ('N334B', 'R341', '75 AV'))
# (587, ('R216', 'R322', 'SPRING ST'))
# (583, ('N337', 'R255', 'BRIARWOOD'))
# (560, ('H016', 'R250', 'GRAND ST'))
# (548, ('N212', 'R253', '174-175 STS'))
# (543, ('J035', 'R008', '111 ST'))
# (536, ('R641', 'R210', 'BEVERLY RD'))
# (535, ('S101', 'R070', 'ST. GEORGE'))
# (533, ('J028', 'R004', '75 ST-ELDERTS'))
# (530, ('B020', 'R263', 'AVENUE H'))
# (526, ('H035', 'R348', 'ATLANTIC AV'))
# (522, ('H014', 'R249', 'GRAHAM AV'))
# (513, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (508, ('R190', 'R038', '215 ST'))
# (508, ('N118', 'R199', 'KINGSTON-THROOP'))
# (493, ('R506', 'R276', 'VERNON-JACKSON'))
# (490, ('R416', 'R245', 'ST LAWRENCE AV'))
# (469, ('N192', 'R336', 'BEACH 60 ST'))
# (461, ('K026', 'R100', 'METROPOLITAN AV'))
# (451, ('C011', 'R231', 'UNION ST'))
# (446, ('B017', 'R262', 'BEVERLEY ROAD'))
# (444, ('N332', 'R219', '67 AV'))
# (444, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (439, ('N111', 'R284', 'CLINTON-WASH AV'))
# (429, ('H003', 'R163', '6 AV'))
# (422, ('C017', 'R455', '25 ST'))
# (409, ('J030', 'R005', '85 ST-FOREST PK'))
# (408, ('R633', 'R068', 'VAN SICLEN AV'))
# (403, ('R617', 'R058', 'BERGEN ST'))
# (392, ('N561', 'R271', 'AVENUE X'))
# (391, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (381, ('N545', 'R204', 'CHURCH AV'))
# (347, ('H033', 'R313', 'BUSHWICK AV'))
# (329, ('N206', 'R104', '167 ST'))
# (310, ('N556', 'R424', 'AVENUE P'))
# (282, ('R413', 'R325', 'WHITLOCK AV'))
# (270, ('R618', 'R058', 'BERGEN ST'))
# (251, ('H030', 'R266', 'HALSEY ST'))
# (246, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (218, ('N195', 'R358', 'BEACH 25 ST'))
# (211, ('J025', 'R003', 'CYPRESS HILLS'))
# (210, ('J037', 'R009', '121 ST'))
# (190, ('C026', 'R215', '86 ST'))
# (183, ('B034', 'R264', 'OCEAN PKWY'))
# (178, ('N194', 'R338', 'BEACH 36 ST'))
# (175, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (157, ('J034', 'R007', '104 ST'))
# (153, ('N339', 'R114', 'PARSONS BLVD'))
# (120, ('N137', 'R354', '104 ST'))
# (106, ('N193', 'R337', 'BEACH 44 ST'))
# (0, ('OB01', 'R459', 'ORCHARD BEACH'))
# (0, ('N550', 'R242', '18 AV'))

# %%
#Tuesday Evening

tuesday = MTA[MTA.DATE == '06/13/2017']
tuesday = tuesday.reset_index(drop=True)

tue_evening=tuesday[(tuesday.TIME =="16:00:00")|(tuesday.TIME == "17:00:00")|(tuesday.TIME =="18:00:00")|(tuesday.TIME == "19:00:00")|(tuesday.TIME == "20:00:00")]
tue_evening = tue_evening.reset_index(drop=True)

tue_evening_dict={}
for i in range(len(tue_evening.index)):
    mytuple= (tue_evening['C/A'][i], tue_evening.UNIT[i], tue_evening.SCP[i], tue_evening.STATION[i])
    if mytuple not in tue_evening_dict.keys():
        tue_evening_dict[mytuple]={tue_evening.TIME[i]:tue_evening.ENTRIES[i]}
    else:
        tue_evening_dict[mytuple][tue_evening.TIME[i]]=tue_evening.ENTRIES[i]

bad_key = []
for key, value in tue_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in tue_evening_dict:
        del tue_evening_dict[key]

tue_evening_differences = {}
for turnstile,times in tue_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in tue_evening_differences:
        tue_evening_differences[mytuple]={turnstile[2]:count}
    else:
        tue_evening_differences[mytuple][turnstile[2]]=count

total_tue_evening_diff = {}
for key, value in tue_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_tue_evening_diff[key] = count
    
tue_evening_passengers = []
for key, value in total_tue_evening_diff.items():
    tue_evening_passengers.append((value, key))
tue_evening_passengers.sort(reverse=True)
for line in tue_evening_passengers:
    print(line)
# Out:
# (19861, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (18712, ('N500', 'R020', '47-50 STS ROCK'))
# (16636, ('N051', 'R084', '59 ST COLUMBUS'))
# (14665, ('N501', 'R020', '47-50 STS ROCK'))
# (14319, ('N306', 'R017', 'LEXINGTON AV/53'))
# (13421, ('N505', 'R022', '34 ST-HERALD SQ'))
# (11762, ('N504', 'R021', '42 ST-BRYANT PK'))
# (11456, ('R250', 'R179', '86 ST'))
# (10044, ('N092', 'R029', 'CHAMBERS ST'))
# (9840, ('N506', 'R022', '34 ST-HERALD SQ'))
# (9833, ('R116', 'R030', 'CHAMBERS ST'))
# (9286, ('R200A', 'R041', 'BOWLING GREEN'))
# (9167, ('N103', 'R127', 'JAY ST-METROTEC'))
# (8958, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (8957, ('N502', 'R021', '42 ST-BRYANT PK'))
# (8865, ('N094', 'R029', 'WORLD TRADE CTR'))
# (8781, ('R533', 'R055', 'FLUSHING-MAIN'))
# (8674, ('A010', 'R080', '57 ST-7 AV'))
# (8529, ('A022', 'R022', '34 ST-HERALD SQ'))
# (8362, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (8254, ('R501', 'R054', '5 AVE'))
# (8077, ('A025', 'R023', '34 ST-HERALD SQ'))
# (7997, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (7909, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (7604, ('N049', 'R084', '59 ST COLUMBUS'))
# (7480, ('N507', 'R023', '34 ST-HERALD SQ'))
# (7270, ('A030', 'R083', '23 ST'))
# (7263, ('N102', 'R127', 'JAY ST-METROTEC'))
# (7165, ('R244A', 'R050', '59 ST'))
# (7118, ('R154', 'R116', '50 ST'))
# (6963, ('N509', 'R203', '23 ST'))
# (6878, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (6836, ('N520', 'R240', 'GRAND ST'))
# (6836, ('N089', 'R139', 'CANAL ST'))
# (6766, ('R182', 'R035', '168 ST'))
# (6680, ('H009', 'R235', 'BEDFORD AV'))
# (6614, ('N091', 'R029', 'CHAMBERS ST'))
# (6564, ('N026', 'R102', '125 ST'))
# (6434, ('A002', 'R051', '59 ST'))
# (6324, ('R155', 'R116', '50 ST'))
# (6166, ('R602', 'R108', 'BOROUGH HALL'))
# (6090, ('N501A', 'R020', '47-50 STS ROCK'))
# (6064, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (6028, ('R245A', 'R051', '59 ST'))
# (5995, ('C008', 'R099', 'DEKALB AV'))
# (5903, ('R110', 'R027', 'WALL ST'))
# (5665, ('N606', 'R025', 'JAMAICA CENTER'))
# (5577, ('R158', 'R084', '59 ST COLUMBUS'))
# (5540, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (5539, ('R111', 'R027', 'WALL ST'))
# (5485, ('R242', 'R049', '51 ST'))
# (5451, ('N400A', 'R359', 'COURT SQ'))
# (5427, ('R217A', 'R194', 'BLEECKER ST'))
# (5397, ('R141', 'R031', '34 ST-PENN STA'))
# (5336, ('R243', 'R049', '51 ST'))
# (5319, ('A015', 'R081', '49 ST'))
# (5283, ('A011', 'R080', '57 ST-7 AV'))
# (5276, ('N503', 'R021', '42 ST-BRYANT PK'))
# (5161, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (5142, ('S101A', 'R070', 'ST. GEORGE'))
# (5117, ('R244', 'R050', '59 ST'))
# (5114, ('R201', 'R041', 'BOWLING GREEN'))
# (5108, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (5054, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (4989, ('N076', 'R111', '23 ST'))
# (4944, ('R249', 'R179', '86 ST'))
# (4859, ('R550', 'R072', '34 ST-HUDSON YD'))
# (4807, ('N072', 'R012', '34 ST-PENN STA'))
# (4743, ('A041', 'R086', 'PRINCE ST'))
# (4719, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (4688, ('N057', 'R188', '50 ST'))
# (4675, ('A031', 'R083', '23 ST'))
# (4609, ('N086', 'R282', 'SPRING ST'))
# (4491, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (4348, ('N067', 'R012', '34 ST-PENN STA'))
# (4298, ('A038', 'R085', '8 ST-NYU'))
# (4247, ('R127', 'R105', '14 ST'))
# (4242, ('R516', 'R291', '33 ST-RAWSON ST'))
# (4219, ('N305', 'R017', 'LEXINGTON AV/53'))
# (4071, ('N068', 'R012', '34 ST-PENN STA'))
# (4036, ('N508', 'R453', '23 ST'))
# (3978, ('N090', 'R139', 'CANAL ST'))
# (3882, ('A027', 'R082', '28 ST'))
# (3877, ('R215', 'R322', 'SPRING ST'))
# (3858, ('N108', 'R217', 'HOYT-SCHER'))
# (3843, ('N063', 'R011', '42 ST-PORT AUTH'))
# (3834, ('R526', 'R096', '82 ST-JACKSON H'))
# (3807, ('N020', 'R101', '145 ST'))
# (3803, ('A047', 'R087', 'CITY HALL'))
# (3712, ('N043', 'R186', '86 ST'))
# (3674, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (3549, ('N601', 'R319', 'LEXINGTON AV/63'))
# (3424, ('H008', 'R248', '1 AV'))
# (3423, ('N046', 'R281', '72 ST'))
# (3393, ('R601A', 'R108', 'BOROUGH HALL'))
# (3389, ('N070', 'R012', '34 ST-PENN STA'))
# (3369, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3359, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (3327, ('H007', 'R248', '1 AV'))
# (3314, ('A013', 'R081', '49 ST'))
# (3278, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (3237, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (3218, ('R129', 'R321', '18 ST'))
# (3161, ('R528', 'R097', 'JUNCTION BLVD'))
# (3153, ('N307', 'R359', 'COURT SQ-23 ST'))
# (3125, ('N056', 'R188', '50 ST'))
# (3004, ('R604', 'R108', 'BOROUGH HALL'))
# (2987, ('R112', 'R027', 'WALL ST'))
# (2977, ('N069', 'R013', '34 ST-PENN STA'))
# (2935, ('A069', 'R044', 'CHAMBERS ST'))
# (2901, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (2865, ('R534', 'R055', 'FLUSHING-MAIN'))
# (2865, ('N062', 'R011', '42 ST-PORT AUTH'))
# (2831, ('C012', 'R258', '4AV-9 ST'))
# (2802, ('R112A', 'R027', 'WALL ST'))
# (2798, ('R527', 'R122', '90 ST-ELMHURST'))
# (2787, ('N523', 'R300', '2 AV'))
# (2753, ('R529', 'R208', '103 ST-CORONA'))
# (2740, ('R183', 'R260', '181 ST'))
# (2734, ('A029', 'R082', '28 ST'))
# (2733, ('N511', 'R163', '14 ST'))
# (2641, ('R310', 'R053', '3 AV-149 ST'))
# (2634, ('N528', 'R257', 'EAST BROADWAY'))
# (2620, ('N405', 'R239', 'GREENPOINT AV'))
# (2609, ('N330', 'R202', '63 DR-REGO PARK'))
# (2561, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (2526, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (2506, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2428, ('R515', 'R095', 'ASTORIA DITMARS'))
# (2424, ('R289', 'R119', 'FORDHAM RD'))
# (2410, ('R306', 'R207', '135 ST'))
# (2377, ('R518', 'R261', '40 ST LOWERY ST'))
# (2364, ('R202', 'R042', 'BOWLING GREEN'))
# (2357, ('R137', 'R031', '34 ST-PENN STA'))
# (2346, ('N071', 'R013', '34 ST-PENN STA'))
# (2346, ('B029', 'R172', 'BRIGHTON BEACH'))
# (2310, ('N039', 'R251', '96 ST'))
# (2308, ('N077', 'R111', '23 ST'))
# (2301, ('R301', 'R323', 'CENTRAL PK N110'))
# (2297, ('R513', 'R093', '30 AV'))
# (2282, ('R606', 'R225', 'HOYT ST'))
# (2273, ('N512', 'R163', '14 ST'))
# (2245, ('R103', 'R304', 'RECTOR ST'))
# (2243, ('R261', 'R205', '149/GRAND CONC'))
# (2228, ('R128', 'R105', '14 ST'))
# (2201, ('N100', 'R252', 'HIGH ST'))
# (2175, ('N408A', 'R256', 'NASSAU AV'))
# (2160, ('R125', 'R189', 'CHRISTOPHER ST'))
# (2159, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (2158, ('N075', 'R111', '23 ST'))
# (2109, ('A054', 'R227', 'RECTOR ST'))
# (2098, ('A016', 'R081', '49 ST'))
# (2092, ('N535', 'R220', 'CARROLL ST'))
# (2086, ('R115', 'R029', 'PARK PLACE'))
# (2063, ('N010', 'R126', '175 ST'))
# (2061, ('R512', 'R092', 'BROADWAY'))
# (2054, ('R608', 'R056', 'NEVINS ST'))
# (2044, ('R174', 'R034', '125 ST'))
# (2039, ('A071', 'R044', 'CHAMBERS ST'))
# (2033, ('R287', 'R244', 'BURNSIDE AV'))
# (2012, ('N315', 'R238', 'STEINWAY ST'))
# (2007, ('R102', 'R304', 'RECTOR ST'))
# (2000, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (1998, ('N116', 'R198', 'NOSTRAND AV'))
# (1974, ('N087', 'R282', 'SPRING ST'))
# (1968, ('N325A', 'R218', 'ELMHURST AV'))
# (1961, ('H019', 'R294', 'MORGAN AV'))
# (1954, ('B016', 'R098', 'CHURCH AV'))
# (1944, ('R194', 'R040', '231 ST'))
# (1918, ('R508', 'R346', 'COURT SQ'))
# (1885, ('N510', 'R163', '14 ST'))
# (1874, ('N529', 'R257', 'EAST BROADWAY'))
# (1863, ('H006', 'R330', '3 AV'))
# (1853, ('N124', 'R103', 'BROADWAY JCT'))
# (1849, ('A014', 'R081', '49 ST'))
# (1844, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1841, ('N521', 'R300', '2 AV'))
# (1834, ('R504', 'R276', 'VERNON-JACKSON'))
# (1827, ('N025', 'R102', '125 ST'))
# (1811, ('H022', 'R279', 'JEFFERSON ST'))
# (1789, ('C019', 'R232', '45 ST'))
# (1780, ('C025', 'R215', '86 ST'))
# (1758, ('R311', 'R053', '3 AV-149 ST'))
# (1734, ('R514', 'R094', 'ASTORIA BLVD'))
# (1726, ('R245', 'R051', '59 ST'))
# (1722, ('R185', 'R274', '191 ST'))
# (1716, ('A042', 'R086', 'PRINCE ST'))
# (1696, ('R283', 'R221', '167 ST'))
# (1690, ('B024', 'R211', 'KINGS HWY'))
# (1665, ('R519', 'R223', '46 ST BLISS ST'))
# (1660, ('N117', 'R198', 'NOSTRAND AV'))
# (1656, ('R600', 'R224', 'CLARK ST'))
# (1651, ('N217', 'R112', 'FORDHAM RD'))
# (1651, ('N073', 'R013', '34 ST-PENN STA'))
# (1620, ('H017', 'R265', 'MONTROSE AV'))
# (1619, ('C021', 'R212', '59 ST'))
# (1614, ('R420', 'R107', 'WESTCHESTER SQ'))
# (1609, ('N128', 'R200', 'EUCLID AV'))
# (1597, ('R284', 'R243', '170 ST'))
# (1596, ('N013', 'R035', '168 ST'))
# (1589, ('N343', 'R019', 'JAMAICA 179 ST'))
# (1579, ('R254', 'R181', '110 ST'))
# (1546, ('R530', 'R310', '111 ST'))
# (1538, ('H013', 'R249', 'GRAHAM AV'))
# (1537, ('R188', 'R037', '207 ST'))
# (1522, ('R139', 'R031', '34 ST-PENN STA'))
# (1489, ('R186', 'R036', 'DYCKMAN ST'))
# (1476, ('N012', 'R035', '168 ST'))
# (1475, ('R511', 'R091', '36 AV'))
# (1447, ('N422', 'R318', 'FULTON ST'))
# (1440, ('A039', 'R085', '8 ST-NYU'))
# (1438, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1425, ('A055', 'R227', 'RECTOR ST'))
# (1414, ('R517', 'R291', '33 ST-RAWSON ST'))
# (1403, ('N546', 'R204', 'CHURCH AV'))
# (1399, ('H015', 'R250', 'GRAND ST'))
# (1393, ('R178', 'R273', '145 ST'))
# (1387, ('B031', 'R172', 'BRIGHTON BEACH'))
# (1382, ('N537', 'R258', '4 AV-9 ST'))
# (1377, ('N040', 'R251', '96 ST'))
# (1375, ('R135', 'R031', '34 ST-PENN STA'))
# (1369, ('N513', 'R163', '14 ST'))
# (1368, ('N536', 'R270', 'SMITH-9 ST'))
# (1344, ('R609', 'R056', 'NEVINS ST'))
# (1341, ('A064', 'R311', 'BOWERY'))
# (1336, ('B022', 'R229', 'AVENUE M'))
# (1321, ('H023', 'R236', 'DEKALB AV'))
# (1318, ('C022', 'R212', '59 ST'))
# (1312, ('N207', 'R104', '167 ST'))
# (1308, ('R307', 'R207', '135 ST'))
# (1308, ('R294', 'R052', 'WOODLAWN'))
# (1293, ('B021', 'R228', 'AVENUE J'))
# (1287, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1283, ('N314', 'R238', 'STEINWAY ST'))
# (1266, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1248, ('R253', 'R181', '110 ST'))
# (1248, ('N101', 'R252', 'HIGH ST'))
# (1247, ('B023', 'R211', 'KINGS HWY'))
# (1236, ('R242A', 'R049', '51 ST'))
# (1206, ('R260', 'R205', '149/GRAND CONC'))
# (1201, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (1198, ('N019', 'R101', '145 ST'))
# (1164, ('C024', 'R214', '77 ST'))
# (1159, ('R192', 'R039', 'MARBLE HILL-225'))
# (1151, ('R286', 'R309', '176 ST'))
# (1150, ('R503', 'R276', 'VERNON-JACKSON'))
# (1145, ('R197', 'R117', 'V.CORTLANDT PK'))
# (1134, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (1124, ('N607', 'R025', 'JAMAICA CENTER'))
# (1123, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (1121, ('R605', 'R456', 'HOYT ST'))
# (1108, ('N218', 'R112', 'FORDHAM RD'))
# (1087, ('R510', 'R090', '39 AV'))
# (1068, ('R285', 'R308', 'MT EDEN AV'))
# (1066, ('N196', 'R285', 'FAR ROCKAWAY'))
# (1063, ('H028', 'R266', 'HALSEY ST'))
# (1062, ('R629', 'R065', 'ROCKAWAY AV'))
# (1026, ('N339A', 'R114', 'PARSONS BLVD'))
# (1020, ('N549', 'R242', '18 AV'))
# (1013, ('B013', 'R196', 'PROSPECT PARK'))
# (1008, ('R634', 'R069', 'NEW LOTS AV'))
# (1007, ('N534', 'R220', 'CARROLL ST'))
# (1003, ('R622', 'R123', 'FRANKLIN AV'))
# (1002, ('E012', 'R372', '18 AV'))
# (988, ('B024A', 'R211', 'KINGS HWY'))
# (982, ('C016', 'R278', '25 ST'))
# (978, ('C010', 'R231', 'UNION ST'))
# (977, ('B018', 'R184', 'CORTELYOU RD'))
# (976, ('N419', 'R287', 'CLASSON AV'))
# (967, ('R636', 'R209', 'STERLING ST'))
# (960, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (960, ('E004', 'R234', '50 ST'))
# (955, ('R418', 'R106', 'CASTLE HILL AV'))
# (945, ('R288', 'R275', '183 ST'))
# (940, ('R624', 'R124', 'KINGSTON AV'))
# (938, ('R259', 'R307', '138/GRAND CONC'))
# (929, ('R520', 'R223', '46 ST BLISS ST'))
# (926, ('C003', 'R089', 'JAY ST-METROTEC'))
# (925, ('N342', 'R019', 'JAMAICA 179 ST'))
# (913, ('R130', 'R321', '18 ST'))
# (911, ('N006A', 'R280', '190 ST'))
# (889, ('N340A', 'R115', '169 ST'))
# (885, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (879, ('R628', 'R064', 'SARATOGA AV'))
# (879, ('B012', 'R196', 'PROSPECT PARK'))
# (860, ('C004', 'R089', 'JAY ST-METROTEC'))
# (855, ('R623', 'R061', 'NOSTRAND AV'))
# (852, ('R525', 'R018', '74 ST-BROADWAY'))
# (842, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (839, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (833, ('N119', 'R199', 'KINGSTON-THROOP'))
# (807, ('H005', 'R330', '3 AV'))
# (799, ('B015', 'R098', 'CHURCH AV'))
# (789, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (786, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (768, ('N129', 'R382', 'GRANT AV'))
# (768, ('E011', 'R371', '79 ST'))
# (765, ('N215', 'R237', '182-183 STS'))
# (764, ('N331', 'R219', '67 AV'))
# (748, ('R635', 'R277', 'PRESIDENT ST'))
# (744, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (738, ('C001', 'R108', 'BOROUGH HALL'))
# (726, ('H032', 'R295', 'WILSON AV'))
# (719, ('N330C', 'R202', '63 DR-REGO PARK'))
# (711, ('R177', 'R273', '145 ST'))
# (710, ('R309', 'R345', 'HARLEM 148 ST'))
# (699, ('N191', 'R335', 'BEACH 67 ST'))
# (697, ('E013', 'R373', '20 AV'))
# (685, ('E009', 'R370', '71 ST'))
# (677, ('H016', 'R250', 'GRAND ST'))
# (676, ('R728', 'R226', 'GUN HILL RD'))
# (674, ('K026', 'R100', 'METROPOLITAN AV'))
# (671, ('R308', 'R344', '145 ST'))
# (651, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (643, ('N334B', 'R341', '75 AV'))
# (634, ('N210', 'R253', '174-175 STS'))
# (633, ('E005', 'R247', '55 ST'))
# (626, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (624, ('B026', 'R230', 'NECK RD'))
# (618, ('N340', 'R115', '169 ST'))
# (613, ('N337', 'R255', 'BRIARWOOD'))
# (610, ('B032', 'R264', 'OCEAN PKWY'))
# (602, ('N011', 'R126', '175 ST'))
# (599, ('N212', 'R253', '174-175 STS'))
# (588, ('H035', 'R348', 'ATLANTIC AV'))
# (586, ('R641', 'R210', 'BEVERLY RD'))
# (586, ('R216', 'R322', 'SPRING ST'))
# (584, ('N111', 'R284', 'CLINTON-WASH AV'))
# (578, ('H014', 'R249', 'GRAHAM AV'))
# (571, ('S101', 'R070', 'ST. GEORGE'))
# (565, ('J035', 'R008', '111 ST'))
# (557, ('B020', 'R263', 'AVENUE H'))
# (542, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (526, ('R126', 'R189', 'CHRISTOPHER ST'))
# (521, ('J028', 'R004', '75 ST-ELDERTS'))
# (510, ('B017', 'R262', 'BEVERLEY ROAD'))
# (506, ('R506', 'R276', 'VERNON-JACKSON'))
# (494, ('C011', 'R231', 'UNION ST'))
# (490, ('R416', 'R245', 'ST LAWRENCE AV'))
# (486, ('R190', 'R038', '215 ST'))
# (480, ('N332', 'R219', '67 AV'))
# (465, ('N192', 'R336', 'BEACH 60 ST'))
# (464, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (464, ('J030', 'R005', '85 ST-FOREST PK'))
# (460, ('R617', 'R058', 'BERGEN ST'))
# (438, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (437, ('C017', 'R455', '25 ST'))
# (434, ('N545', 'R204', 'CHURCH AV'))
# (428, ('N118', 'R199', 'KINGSTON-THROOP'))
# (416, ('R633', 'R068', 'VAN SICLEN AV'))
# (416, ('N561', 'R271', 'AVENUE X'))
# (415, ('H033', 'R313', 'BUSHWICK AV'))
# (370, ('N206', 'R104', '167 ST'))
# (357, ('H003', 'R163', '6 AV'))
# (356, ('R413', 'R325', 'WHITLOCK AV'))
# (307, ('N556', 'R424', 'AVENUE P'))
# (279, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (275, ('R618', 'R058', 'BERGEN ST'))
# (273, ('N195', 'R358', 'BEACH 25 ST'))
# (251, ('H030', 'R266', 'HALSEY ST'))
# (224, ('C026', 'R215', '86 ST'))
# (218, ('J037', 'R009', '121 ST'))
# (211, ('J025', 'R003', 'CYPRESS HILLS'))
# (194, ('B034', 'R264', 'OCEAN PKWY'))
# (184, ('J034', 'R007', '104 ST'))
# (181, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (154, ('N339', 'R114', 'PARSONS BLVD'))
# (149, ('N194', 'R338', 'BEACH 36 ST'))
# (130, ('N137', 'R354', '104 ST'))
# (112, ('N193', 'R337', 'BEACH 44 ST'))
# (14, ('OB01', 'R459', 'ORCHARD BEACH'))
# (0, ('N550', 'R242', '18 AV'))

# %%
#Wednesday evening
wednesday = MTA[MTA.DATE == '06/14/2017']
wednesday = wednesday.reset_index(drop=True)

wed_evening=wednesday[(wednesday.TIME =="16:00:00")|(wednesday.TIME == "17:00:00")|(wednesday.TIME =="18:00:00")|(wednesday.TIME == "19:00:00")|(wednesday.TIME == "20:00:00")]
wed_evening = wed_evening.reset_index(drop=True)

wed_evening_dict={}
for i in range(len(wed_evening.index)):
    mytuple= (wed_evening['C/A'][i], wed_evening.UNIT[i], wed_evening.SCP[i], wed_evening.STATION[i])
    if mytuple not in wed_evening_dict.keys():
        wed_evening_dict[mytuple]={wed_evening.TIME[i]:wed_evening.ENTRIES[i]}
    else:
        wed_evening_dict[mytuple][wed_evening.TIME[i]]=wed_evening.ENTRIES[i]

bad_key = []
for key, value in wed_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in wed_evening_dict:
        del wed_evening_dict[key]

wed_evening_differences = {}
for turnstile,times in wed_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in wed_evening_differences:
        wed_evening_differences[mytuple]={turnstile[2]:count}
    else:
        wed_evening_differences[mytuple][turnstile[2]]=count

total_wed_evening_diff = {}
for key, value in wed_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_wed_evening_diff[key] = count
    
wed_evening_passengers = []
for key, value in total_wed_evening_diff.items():
    wed_evening_passengers.append((value, key))
wed_evening_passengers.sort(reverse=True)
for line in wed_evening_passengers:
    print(line)
# Out:
# (20287, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (18057, ('N500', 'R020', '47-50 STS ROCK'))
# (17176, ('N051', 'R084', '59 ST COLUMBUS'))
# (14475, ('N306', 'R017', 'LEXINGTON AV/53'))
# (14358, ('N501', 'R020', '47-50 STS ROCK'))
# (13143, ('N505', 'R022', '34 ST-HERALD SQ'))
# (11795, ('N504', 'R021', '42 ST-BRYANT PK'))
# (10348, ('R250', 'R179', '86 ST'))
# (10271, ('R116', 'R030', 'CHAMBERS ST'))
# (10250, ('N506', 'R022', '34 ST-HERALD SQ'))
# (10027, ('N092', 'R029', 'CHAMBERS ST'))
# (9907, ('N520', 'R240', 'GRAND ST'))
# (9432, ('R200A', 'R041', 'BOWLING GREEN'))
# (9408, ('N103', 'R127', 'JAY ST-METROTEC'))
# (9209, ('R533', 'R055', 'FLUSHING-MAIN'))
# (9150, ('N502', 'R021', '42 ST-BRYANT PK'))
# (8984, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (8885, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (8748, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (8725, ('A010', 'R080', '57 ST-7 AV'))
# (8710, ('A022', 'R022', '34 ST-HERALD SQ'))
# (8470, ('N094', 'R029', 'WORLD TRADE CTR'))
# (8348, ('R501', 'R054', '5 AVE'))
# (8153, ('N049', 'R084', '59 ST COLUMBUS'))
# (7937, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (7406, ('A030', 'R083', '23 ST'))
# (7280, ('N102', 'R127', 'JAY ST-METROTEC'))
# (7278, ('N507', 'R023', '34 ST-HERALD SQ'))
# (7245, ('R154', 'R116', '50 ST'))
# (7121, ('A025', 'R023', '34 ST-HERALD SQ'))
# (7057, ('R244A', 'R050', '59 ST'))
# (7044, ('N091', 'R029', 'CHAMBERS ST'))
# (7036, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (7013, ('N509', 'R203', '23 ST'))
# (6967, ('N026', 'R102', '125 ST'))
# (6932, ('H009', 'R235', 'BEDFORD AV'))
# (6844, ('N089', 'R139', 'CANAL ST'))
# (6599, ('R155', 'R116', '50 ST'))
# (6514, ('A002', 'R051', '59 ST'))
# (6499, ('R182', 'R035', '168 ST'))
# (6359, ('C008', 'R099', 'DEKALB AV'))
# (6165, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (6035, ('R110', 'R027', 'WALL ST'))
# (6028, ('R602', 'R108', 'BOROUGH HALL'))
# (5988, ('R158', 'R084', '59 ST COLUMBUS'))
# (5900, ('N501A', 'R020', '47-50 STS ROCK'))
# (5893, ('N606', 'R025', 'JAMAICA CENTER'))
# (5812, ('R245A', 'R051', '59 ST'))
# (5790, ('R217A', 'R194', 'BLEECKER ST'))
# (5720, ('N503', 'R021', '42 ST-BRYANT PK'))
# (5686, ('R141', 'R031', '34 ST-PENN STA'))
# (5670, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (5572, ('R242', 'R049', '51 ST'))
# (5560, ('R111', 'R027', 'WALL ST'))
# (5535, ('A015', 'R081', '49 ST'))
# (5422, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (5411, ('N076', 'R111', '23 ST'))
# (5372, ('S101A', 'R070', 'ST. GEORGE'))
# (5315, ('R243', 'R049', '51 ST'))
# (5280, ('N072', 'R012', '34 ST-PENN STA'))
# (5273, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (5163, ('R244', 'R050', '59 ST'))
# (5146, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (5134, ('N400A', 'R359', 'COURT SQ'))
# (5088, ('R550', 'R072', '34 ST-HUDSON YD'))
# (5087, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (5069, ('A041', 'R086', 'PRINCE ST'))
# (5067, ('N057', 'R188', '50 ST'))
# (5029, ('R201', 'R041', 'BOWLING GREEN'))
# (4911, ('A011', 'R080', '57 ST-7 AV'))
# (4826, ('R249', 'R179', '86 ST'))
# (4821, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (4787, ('N086', 'R282', 'SPRING ST'))
# (4743, ('A031', 'R083', '23 ST'))
# (4627, ('N508', 'R453', '23 ST'))
# (4464, ('N067', 'R012', '34 ST-PENN STA'))
# (4387, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (4370, ('R127', 'R105', '14 ST'))
# (4333, ('A038', 'R085', '8 ST-NYU'))
# (4242, ('N305', 'R017', 'LEXINGTON AV/53'))
# (4145, ('N068', 'R012', '34 ST-PENN STA'))
# (4058, ('N090', 'R139', 'CANAL ST'))
# (4022, ('N020', 'R101', '145 ST'))
# (4014, ('N108', 'R217', 'HOYT-SCHER'))
# (3830, ('N046', 'R281', '72 ST'))
# (3781, ('R526', 'R096', '82 ST-JACKSON H'))
# (3756, ('N063', 'R011', '42 ST-PORT AUTH'))
# (3713, ('R215', 'R322', 'SPRING ST'))
# (3663, ('N043', 'R186', '86 ST'))
# (3656, ('H008', 'R248', '1 AV'))
# (3646, ('A027', 'R082', '28 ST'))
# (3640, ('R516', 'R291', '33 ST-RAWSON ST'))
# (3604, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (3583, ('N070', 'R012', '34 ST-PENN STA'))
# (3581, ('N601', 'R319', 'LEXINGTON AV/63'))
# (3560, ('R601A', 'R108', 'BOROUGH HALL'))
# (3497, ('N056', 'R188', '50 ST'))
# (3462, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3455, ('A047', 'R087', 'CITY HALL'))
# (3433, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (3423, ('H007', 'R248', '1 AV'))
# (3359, ('R528', 'R097', 'JUNCTION BLVD'))
# (3325, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (3322, ('A013', 'R081', '49 ST'))
# (3283, ('R129', 'R321', '18 ST'))
# (3229, ('N307', 'R359', 'COURT SQ-23 ST'))
# (3022, ('R604', 'R108', 'BOROUGH HALL'))
# (2999, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (2988, ('N069', 'R013', '34 ST-PENN STA'))
# (2975, ('R534', 'R055', 'FLUSHING-MAIN'))
# (2945, ('R112', 'R027', 'WALL ST'))
# (2891, ('R529', 'R208', '103 ST-CORONA'))
# (2878, ('N062', 'R011', '42 ST-PORT AUTH'))
# (2874, ('N523', 'R300', '2 AV'))
# (2857, ('R527', 'R122', '90 ST-ELMHURST'))
# (2843, ('C012', 'R258', '4AV-9 ST'))
# (2839, ('A069', 'R044', 'CHAMBERS ST'))
# (2787, ('N330', 'R202', '63 DR-REGO PARK'))
# (2783, ('R112A', 'R027', 'WALL ST'))
# (2738, ('N511', 'R163', '14 ST'))
# (2709, ('R183', 'R260', '181 ST'))
# (2707, ('N405', 'R239', 'GREENPOINT AV'))
# (2692, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (2666, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (2560, ('A029', 'R082', '28 ST'))
# (2553, ('R515', 'R095', 'ASTORIA DITMARS'))
# (2550, ('R289', 'R119', 'FORDHAM RD'))
# (2545, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2503, ('N528', 'R257', 'EAST BROADWAY'))
# (2467, ('R306', 'R207', '135 ST'))
# (2422, ('R513', 'R093', '30 AV'))
# (2421, ('R125', 'R189', 'CHRISTOPHER ST'))
# (2387, ('R518', 'R261', '40 ST LOWERY ST'))
# (2383, ('R261', 'R205', '149/GRAND CONC'))
# (2375, ('N071', 'R013', '34 ST-PENN STA'))
# (2334, ('R202', 'R042', 'BOWLING GREEN'))
# (2332, ('R137', 'R031', '34 ST-PENN STA'))
# (2315, ('R301', 'R323', 'CENTRAL PK N110'))
# (2307, ('R128', 'R105', '14 ST'))
# (2290, ('N039', 'R251', '96 ST'))
# (2283, ('N075', 'R111', '23 ST'))
# (2281, ('N100', 'R252', 'HIGH ST'))
# (2276, ('R310', 'R053', '3 AV-149 ST'))
# (2241, ('A016', 'R081', '49 ST'))
# (2234, ('R103', 'R304', 'RECTOR ST'))
# (2227, ('R174', 'R034', '125 ST'))
# (2215, ('R115', 'R029', 'PARK PLACE'))
# (2214, ('R608', 'R056', 'NEVINS ST'))
# (2204, ('N116', 'R198', 'NOSTRAND AV'))
# (2202, ('N408A', 'R256', 'NASSAU AV'))
# (2200, ('N512', 'R163', '14 ST'))
# (2198, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (2179, ('R606', 'R225', 'HOYT ST'))
# (2176, ('N315', 'R238', 'STEINWAY ST'))
# (2163, ('A054', 'R227', 'RECTOR ST'))
# (2160, ('N077', 'R111', '23 ST'))
# (2147, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (2139, ('H019', 'R294', 'MORGAN AV'))
# (2119, ('A071', 'R044', 'CHAMBERS ST'))
# (2108, ('N535', 'R220', 'CARROLL ST'))
# (2098, ('R512', 'R092', 'BROADWAY'))
# (2092, ('A014', 'R081', '49 ST'))
# (2057, ('R287', 'R244', 'BURNSIDE AV'))
# (2057, ('N010', 'R126', '175 ST'))
# (2043, ('B029', 'R172', 'BRIGHTON BEACH'))
# (2017, ('R508', 'R346', 'COURT SQ'))
# (2015, ('B016', 'R098', 'CHURCH AV'))
# (1997, ('C025', 'R215', '86 ST'))
# (1996, ('R102', 'R304', 'RECTOR ST'))
# (1994, ('R194', 'R040', '231 ST'))
# (1977, ('R504', 'R276', 'VERNON-JACKSON'))
# (1958, ('N510', 'R163', '14 ST'))
# (1958, ('B024', 'R211', 'KINGS HWY'))
# (1955, ('N124', 'R103', 'BROADWAY JCT'))
# (1948, ('N325A', 'R218', 'ELMHURST AV'))
# (1916, ('N521', 'R300', '2 AV'))
# (1904, ('H022', 'R279', 'JEFFERSON ST'))
# (1881, ('C019', 'R232', '45 ST'))
# (1842, ('N529', 'R257', 'EAST BROADWAY'))
# (1841, ('H006', 'R330', '3 AV'))
# (1838, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1828, ('R245', 'R051', '59 ST'))
# (1814, ('A042', 'R086', 'PRINCE ST'))
# (1811, ('R514', 'R094', 'ASTORIA BLVD'))
# (1802, ('R311', 'R053', '3 AV-149 ST'))
# (1802, ('N025', 'R102', '125 ST'))
# (1800, ('R600', 'R224', 'CLARK ST'))
# (1794, ('R519', 'R223', '46 ST BLISS ST'))
# (1774, ('R283', 'R221', '167 ST'))
# (1760, ('R284', 'R243', '170 ST'))
# (1720, ('N217', 'R112', 'FORDHAM RD'))
# (1708, ('N117', 'R198', 'NOSTRAND AV'))
# (1701, ('R185', 'R274', '191 ST'))
# (1672, ('N013', 'R035', '168 ST'))
# (1671, ('N073', 'R013', '34 ST-PENN STA'))
# (1669, ('C021', 'R212', '59 ST'))
# (1668, ('H017', 'R265', 'MONTROSE AV'))
# (1665, ('N128', 'R200', 'EUCLID AV'))
# (1657, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1612, ('N343', 'R019', 'JAMAICA 179 ST'))
# (1603, ('N012', 'R035', '168 ST'))
# (1602, ('R254', 'R181', '110 ST'))
# (1594, ('R420', 'R107', 'WESTCHESTER SQ'))
# (1591, ('R511', 'R091', '36 AV'))
# (1566, ('R530', 'R310', '111 ST'))
# (1554, ('H013', 'R249', 'GRAHAM AV'))
# (1528, ('R188', 'R037', '207 ST'))
# (1507, ('A039', 'R085', '8 ST-NYU'))
# (1506, ('R139', 'R031', '34 ST-PENN STA'))
# (1491, ('N422', 'R318', 'FULTON ST'))
# (1478, ('R186', 'R036', 'DYCKMAN ST'))
# (1467, ('B021', 'R228', 'AVENUE J'))
# (1453, ('A064', 'R311', 'BOWERY'))
# (1438, ('N513', 'R163', '14 ST'))
# (1432, ('R609', 'R056', 'NEVINS ST'))
# (1431, ('H015', 'R250', 'GRAND ST'))
# (1427, ('N536', 'R270', 'SMITH-9 ST'))
# (1426, ('N537', 'R258', '4 AV-9 ST'))
# (1423, ('R178', 'R273', '145 ST'))
# (1423, ('N546', 'R204', 'CHURCH AV'))
# (1398, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1386, ('R135', 'R031', '34 ST-PENN STA'))
# (1376, ('N040', 'R251', '96 ST'))
# (1371, ('N207', 'R104', '167 ST'))
# (1367, ('A055', 'R227', 'RECTOR ST'))
# (1365, ('R517', 'R291', '33 ST-RAWSON ST'))
# (1363, ('N101', 'R252', 'HIGH ST'))
# (1359, ('N314', 'R238', 'STEINWAY ST'))
# (1318, ('N019', 'R101', '145 ST'))
# (1316, ('B022', 'R229', 'AVENUE M'))
# (1280, ('C022', 'R212', '59 ST'))
# (1275, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (1272, ('B023', 'R211', 'KINGS HWY'))
# (1264, ('R503', 'R276', 'VERNON-JACKSON'))
# (1250, ('R294', 'R052', 'WOODLAWN'))
# (1248, ('R192', 'R039', 'MARBLE HILL-225'))
# (1242, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (1242, ('R307', 'R207', '135 ST'))
# (1237, ('H023', 'R236', 'DEKALB AV'))
# (1212, ('R253', 'R181', '110 ST'))
# (1210, ('R286', 'R309', '176 ST'))
# (1208, ('R197', 'R117', 'V.CORTLANDT PK'))
# (1180, ('C024', 'R214', '77 ST'))
# (1179, ('R285', 'R308', 'MT EDEN AV'))
# (1178, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1143, ('R605', 'R456', 'HOYT ST'))
# (1140, ('R260', 'R205', '149/GRAND CONC'))
# (1140, ('N218', 'R112', 'FORDHAM RD'))
# (1140, ('H028', 'R266', 'HALSEY ST'))
# (1137, ('R622', 'R123', 'FRANKLIN AV'))
# (1134, ('B013', 'R196', 'PROSPECT PARK'))
# (1132, ('N196', 'R285', 'FAR ROCKAWAY'))
# (1126, ('R242A', 'R049', '51 ST'))
# (1120, ('R510', 'R090', '39 AV'))
# (1096, ('N339A', 'R114', 'PARSONS BLVD'))
# (1089, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (1088, ('N607', 'R025', 'JAMAICA CENTER'))
# (1079, ('R624', 'R124', 'KINGSTON AV'))
# (1066, ('N534', 'R220', 'CARROLL ST'))
# (1056, ('B031', 'R172', 'BRIGHTON BEACH'))
# (1049, ('B024A', 'R211', 'KINGS HWY'))
# (1045, ('E004', 'R234', '50 ST'))
# (1040, ('N419', 'R287', 'CLASSON AV'))
# (1037, ('N549', 'R242', '18 AV'))
# (1035, ('N342', 'R019', 'JAMAICA 179 ST'))
# (1032, ('B018', 'R184', 'CORTELYOU RD'))
# (1029, ('C016', 'R278', '25 ST'))
# (1017, ('E012', 'R372', '18 AV'))
# (998, ('R636', 'R209', 'STERLING ST'))
# (992, ('R629', 'R065', 'ROCKAWAY AV'))
# (990, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (989, ('C010', 'R231', 'UNION ST'))
# (981, ('R288', 'R275', '183 ST'))
# (980, ('R520', 'R223', '46 ST BLISS ST'))
# (965, ('R418', 'R106', 'CASTLE HILL AV'))
# (963, ('R259', 'R307', '138/GRAND CONC'))
# (962, ('R634', 'R069', 'NEW LOTS AV'))
# (925, ('N340A', 'R115', '169 ST'))
# (912, ('R628', 'R064', 'SARATOGA AV'))
# (907, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (893, ('N006A', 'R280', '190 ST'))
# (886, ('R130', 'R321', '18 ST'))
# (869, ('B012', 'R196', 'PROSPECT PARK'))
# (864, ('R623', 'R061', 'NOSTRAND AV'))
# (860, ('C004', 'R089', 'JAY ST-METROTEC'))
# (857, ('C003', 'R089', 'JAY ST-METROTEC'))
# (853, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (852, ('R525', 'R018', '74 ST-BROADWAY'))
# (849, ('B015', 'R098', 'CHURCH AV'))
# (841, ('N129', 'R382', 'GRANT AV'))
# (839, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (835, ('N119', 'R199', 'KINGSTON-THROOP'))
# (826, ('N331', 'R219', '67 AV'))
# (804, ('R635', 'R277', 'PRESIDENT ST'))
# (797, ('N215', 'R237', '182-183 STS'))
# (789, ('H005', 'R330', '3 AV'))
# (782, ('N330C', 'R202', '63 DR-REGO PARK'))
# (779, ('C001', 'R108', 'BOROUGH HALL'))
# (769, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (766, ('H032', 'R295', 'WILSON AV'))
# (738, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (736, ('E011', 'R371', '79 ST'))
# (730, ('R177', 'R273', '145 ST'))
# (729, ('R728', 'R226', 'GUN HILL RD'))
# (713, ('E013', 'R373', '20 AV'))
# (705, ('R308', 'R344', '145 ST'))
# (705, ('N111', 'R284', 'CLINTON-WASH AV'))
# (699, ('R309', 'R345', 'HARLEM 148 ST'))
# (693, ('N334B', 'R341', '75 AV'))
# (680, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (674, ('N210', 'R253', '174-175 STS'))
# (673, ('E005', 'R247', '55 ST'))
# (662, ('N011', 'R126', '175 ST'))
# (660, ('E009', 'R370', '71 ST'))
# (658, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (634, ('B020', 'R263', 'AVENUE H'))
# (630, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (629, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (629, ('N337', 'R255', 'BRIARWOOD'))
# (625, ('H016', 'R250', 'GRAND ST'))
# (620, ('B032', 'R264', 'OCEAN PKWY'))
# (616, ('B026', 'R230', 'NECK RD'))
# (615, ('S101', 'R070', 'ST. GEORGE'))
# (606, ('N340', 'R115', '169 ST'))
# (603, ('N212', 'R253', '174-175 STS'))
# (602, ('R641', 'R210', 'BEVERLY RD'))
# (587, ('K026', 'R100', 'METROPOLITAN AV'))
# (582, ('R126', 'R189', 'CHRISTOPHER ST'))
# (579, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (565, ('H014', 'R249', 'GRAHAM AV'))
# (554, ('R216', 'R322', 'SPRING ST'))
# (550, ('H035', 'R348', 'ATLANTIC AV'))
# (549, ('J035', 'R008', '111 ST'))
# (526, ('R190', 'R038', '215 ST'))
# (525, ('R506', 'R276', 'VERNON-JACKSON'))
# (517, ('R416', 'R245', 'ST LAWRENCE AV'))
# (511, ('C011', 'R231', 'UNION ST'))
# (494, ('N332', 'R219', '67 AV'))
# (492, ('B017', 'R262', 'BEVERLEY ROAD'))
# (474, ('C017', 'R455', '25 ST'))
# (473, ('R617', 'R058', 'BERGEN ST'))
# (471, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (466, ('J030', 'R005', '85 ST-FOREST PK'))
# (463, ('J028', 'R004', '75 ST-ELDERTS'))
# (457, ('N545', 'R204', 'CHURCH AV'))
# (444, ('N191', 'R335', 'BEACH 67 ST'))
# (431, ('N561', 'R271', 'AVENUE X'))
# (428, ('H033', 'R313', 'BUSHWICK AV'))
# (421, ('R633', 'R068', 'VAN SICLEN AV'))
# (416, ('N192', 'R336', 'BEACH 60 ST'))
# (407, ('N118', 'R199', 'KINGSTON-THROOP'))
# (406, ('H003', 'R163', '6 AV'))
# (397, ('N206', 'R104', '167 ST'))
# (323, ('R413', 'R325', 'WHITLOCK AV'))
# (303, ('R618', 'R058', 'BERGEN ST'))
# (296, ('N556', 'R424', 'AVENUE P'))
# (250, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (244, ('N195', 'R358', 'BEACH 25 ST'))
# (238, ('H030', 'R266', 'HALSEY ST'))
# (228, ('C026', 'R215', '86 ST'))
# (226, ('J025', 'R003', 'CYPRESS HILLS'))
# (200, ('J037', 'R009', '121 ST'))
# (196, ('B034', 'R264', 'OCEAN PKWY'))
# (173, ('N339', 'R114', 'PARSONS BLVD'))
# (166, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (162, ('J034', 'R007', '104 ST'))
# (158, ('N194', 'R338', 'BEACH 36 ST'))
# (120, ('N137', 'R354', '104 ST'))
# (98, ('N193', 'R337', 'BEACH 44 ST'))
# (0, ('R630', 'R066', 'JUNIUS ST'))
# (0, ('R627', 'R063', 'SUTTER AV-RUTLD'))
# (0, ('OB01', 'R459', 'ORCHARD BEACH'))
# (0, ('N550', 'R242', '18 AV'))

# %%
#Thursday evening
thursday = MTA[MTA.DATE == '06/15/2017']
thursday = thursday.reset_index(drop=True)

thurs_evening=thursday[(thursday.TIME =="16:00:00")|(thursday.TIME == "17:00:00")|(thursday.TIME =="18:00:00")|(thursday.TIME == "19:00:00")|(thursday.TIME == "20:00:00")]
thurs_evening = thurs_evening.reset_index(drop=True)

thurs_evening_dict={}
for i in range(len(thurs_evening.index)):
    mytuple= (thurs_evening['C/A'][i], thurs_evening.UNIT[i], thurs_evening.SCP[i], thurs_evening.STATION[i])
    if mytuple not in thurs_evening_dict.keys():
        thurs_evening_dict[mytuple]={thurs_evening.TIME[i]:thurs_evening.ENTRIES[i]}
    else:
        thurs_evening_dict[mytuple][thurs_evening.TIME[i]]=thurs_evening.ENTRIES[i]

bad_key = []
for key, value in thurs_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in thurs_evening_dict:
        del thurs_evening_dict[key]

thurs_evening_differences = {}
for turnstile,times in thurs_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in thurs_evening_differences:
        thurs_evening_differences[mytuple]={turnstile[2]:count}
    else:
        thurs_evening_differences[mytuple][turnstile[2]]=count

total_thurs_evening_diff = {}
for key, value in thurs_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_thurs_evening_diff[key] = count
    
thurs_evening_passengers = []
for key, value in total_thurs_evening_diff.items():
    thurs_evening_passengers.append((value, key))
thurs_evening_passengers.sort(reverse=True)
for line in thurs_evening_passengers:
    print(line)
# Out:
# (20175, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (18020, ('N500', 'R020', '47-50 STS ROCK'))
# (16565, ('N051', 'R084', '59 ST COLUMBUS'))
# (14225, ('N306', 'R017', 'LEXINGTON AV/53'))
# (14199, ('N501', 'R020', '47-50 STS ROCK'))
# (13702, ('N506', 'R022', '34 ST-HERALD SQ'))
# (13270, ('N505', 'R022', '34 ST-HERALD SQ'))
# (11583, ('N504', 'R021', '42 ST-BRYANT PK'))
# (10878, ('R250', 'R179', '86 ST'))
# (10199, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (9991, ('R116', 'R030', 'CHAMBERS ST'))
# (9956, ('N520', 'R240', 'GRAND ST'))
# (9796, ('N092', 'R029', 'CHAMBERS ST'))
# (9568, ('N103', 'R127', 'JAY ST-METROTEC'))
# (9198, ('N094', 'R029', 'WORLD TRADE CTR'))
# (9043, ('R533', 'R055', 'FLUSHING-MAIN'))
# (9012, ('R200A', 'R041', 'BOWLING GREEN'))
# (8945, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (8920, ('A022', 'R022', '34 ST-HERALD SQ'))
# (8919, ('N502', 'R021', '42 ST-BRYANT PK'))
# (8901, ('A010', 'R080', '57 ST-7 AV'))
# (8530, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (8125, ('R501', 'R054', '5 AVE'))
# (8102, ('N049', 'R084', '59 ST COLUMBUS'))
# (7616, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (7487, ('N507', 'R023', '34 ST-HERALD SQ'))
# (7260, ('A030', 'R083', '23 ST'))
# (7218, ('N102', 'R127', 'JAY ST-METROTEC'))
# (7103, ('R154', 'R116', '50 ST'))
# (7088, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (7070, ('R244A', 'R050', '59 ST'))
# (7040, ('H009', 'R235', 'BEDFORD AV'))
# (7010, ('N026', 'R102', '125 ST'))
# (6925, ('N509', 'R203', '23 ST'))
# (6904, ('N089', 'R139', 'CANAL ST'))
# (6865, ('N091', 'R029', 'CHAMBERS ST'))
# (6783, ('A025', 'R023', '34 ST-HERALD SQ'))
# (6568, ('A002', 'R051', '59 ST'))
# (6435, ('R182', 'R035', '168 ST'))
# (6327, ('C008', 'R099', 'DEKALB AV'))
# (6219, ('R602', 'R108', 'BOROUGH HALL'))
# (6046, ('R155', 'R116', '50 ST'))
# (5981, ('R110', 'R027', 'WALL ST'))
# (5974, ('R141', 'R031', '34 ST-PENN STA'))
# (5972, ('R245A', 'R051', '59 ST'))
# (5955, ('N606', 'R025', 'JAMAICA CENTER'))
# (5927, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (5866, ('N501A', 'R020', '47-50 STS ROCK'))
# (5795, ('R158', 'R084', '59 ST COLUMBUS'))
# (5704, ('R217A', 'R194', 'BLEECKER ST'))
# (5620, ('N503', 'R021', '42 ST-BRYANT PK'))
# (5598, ('A015', 'R081', '49 ST'))
# (5595, ('R242', 'R049', '51 ST'))
# (5561, ('R111', 'R027', 'WALL ST'))
# (5461, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (5368, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (5251, ('R244', 'R050', '59 ST'))
# (5220, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (5203, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (5144, ('N076', 'R111', '23 ST'))
# (5119, ('R249', 'R179', '86 ST'))
# (5076, ('A041', 'R086', 'PRINCE ST'))
# (5069, ('N400A', 'R359', 'COURT SQ'))
# (5003, ('R550', 'R072', '34 ST-HUDSON YD'))
# (4938, ('S101A', 'R070', 'ST. GEORGE'))
# (4903, ('R201', 'R041', 'BOWLING GREEN'))
# (4901, ('N072', 'R012', '34 ST-PENN STA'))
# (4870, ('N057', 'R188', '50 ST'))
# (4789, ('R243', 'R049', '51 ST'))
# (4785, ('A011', 'R080', '57 ST-7 AV'))
# (4751, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (4726, ('N067', 'R012', '34 ST-PENN STA'))
# (4687, ('A031', 'R083', '23 ST'))
# (4531, ('N086', 'R282', 'SPRING ST'))
# (4520, ('R127', 'R105', '14 ST'))
# (4476, ('A038', 'R085', '8 ST-NYU'))
# (4385, ('N305', 'R017', 'LEXINGTON AV/53'))
# (4274, ('N508', 'R453', '23 ST'))
# (4208, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (4054, ('N020', 'R101', '145 ST'))
# (4012, ('N068', 'R012', '34 ST-PENN STA'))
# (3985, ('N108', 'R217', 'HOYT-SCHER'))
# (3975, ('N090', 'R139', 'CANAL ST'))
# (3972, ('A047', 'R087', 'CITY HALL'))
# (3925, ('N063', 'R011', '42 ST-PORT AUTH'))
# (3892, ('R526', 'R096', '82 ST-JACKSON H'))
# (3868, ('R215', 'R322', 'SPRING ST'))
# (3835, ('N043', 'R186', '86 ST'))
# (3816, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (3753, ('N046', 'R281', '72 ST'))
# (3727, ('R516', 'R291', '33 ST-RAWSON ST'))
# (3688, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3655, ('R601A', 'R108', 'BOROUGH HALL'))
# (3621, ('H008', 'R248', '1 AV'))
# (3591, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (3544, ('N601', 'R319', 'LEXINGTON AV/63'))
# (3533, ('A027', 'R082', '28 ST'))
# (3527, ('N070', 'R012', '34 ST-PENN STA'))
# (3412, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (3360, ('H007', 'R248', '1 AV'))
# (3303, ('R528', 'R097', 'JUNCTION BLVD'))
# (3224, ('N307', 'R359', 'COURT SQ-23 ST'))
# (3150, ('A013', 'R081', '49 ST'))
# (3125, ('R129', 'R321', '18 ST'))
# (3082, ('R534', 'R055', 'FLUSHING-MAIN'))
# (3076, ('R112', 'R027', 'WALL ST'))
# (3066, ('N523', 'R300', '2 AV'))
# (2992, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (2974, ('R527', 'R122', '90 ST-ELMHURST'))
# (2970, ('N069', 'R013', '34 ST-PENN STA'))
# (2948, ('N330', 'R202', '63 DR-REGO PARK'))
# (2918, ('R604', 'R108', 'BOROUGH HALL'))
# (2865, ('C012', 'R258', '4AV-9 ST'))
# (2856, ('R529', 'R208', '103 ST-CORONA'))
# (2819, ('N056', 'R188', '50 ST'))
# (2818, ('A069', 'R044', 'CHAMBERS ST'))
# (2810, ('N062', 'R011', '42 ST-PORT AUTH'))
# (2786, ('R183', 'R260', '181 ST'))
# (2775, ('R112A', 'R027', 'WALL ST'))
# (2760, ('N405', 'R239', 'GREENPOINT AV'))
# (2707, ('N511', 'R163', '14 ST'))
# (2678, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (2659, ('N528', 'R257', 'EAST BROADWAY'))
# (2638, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (2632, ('A029', 'R082', '28 ST'))
# (2630, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2601, ('R515', 'R095', 'ASTORIA DITMARS'))
# (2553, ('R289', 'R119', 'FORDHAM RD'))
# (2534, ('R518', 'R261', '40 ST LOWERY ST'))
# (2497, ('N077', 'R111', '23 ST'))
# (2491, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (2473, ('N512', 'R163', '14 ST'))
# (2464, ('R310', 'R053', '3 AV-149 ST'))
# (2444, ('R301', 'R323', 'CENTRAL PK N110'))
# (2441, ('R202', 'R042', 'BOWLING GREEN'))
# (2433, ('R261', 'R205', '149/GRAND CONC'))
# (2427, ('R306', 'R207', '135 ST'))
# (2416, ('N071', 'R013', '34 ST-PENN STA'))
# (2380, ('R103', 'R304', 'RECTOR ST'))
# (2372, ('R125', 'R189', 'CHRISTOPHER ST'))
# (2355, ('R128', 'R105', '14 ST'))
# (2354, ('R513', 'R093', '30 AV'))
# (2332, ('N116', 'R198', 'NOSTRAND AV'))
# (2328, ('N100', 'R252', 'HIGH ST'))
# (2312, ('R137', 'R031', '34 ST-PENN STA'))
# (2280, ('R608', 'R056', 'NEVINS ST'))
# (2269, ('N039', 'R251', '96 ST'))
# (2264, ('N535', 'R220', 'CARROLL ST'))
# (2260, ('R606', 'R225', 'HOYT ST'))
# (2250, ('A016', 'R081', '49 ST'))
# (2242, ('H019', 'R294', 'MORGAN AV'))
# (2240, ('B016', 'R098', 'CHURCH AV'))
# (2214, ('A054', 'R227', 'RECTOR ST'))
# (2209, ('N315', 'R238', 'STEINWAY ST'))
# (2160, ('N408A', 'R256', 'NASSAU AV'))
# (2149, ('R512', 'R092', 'BROADWAY'))
# (2146, ('R102', 'R304', 'RECTOR ST'))
# (2144, ('N010', 'R126', '175 ST'))
# (2129, ('R287', 'R244', 'BURNSIDE AV'))
# (2125, ('R115', 'R029', 'PARK PLACE'))
# (2116, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (2110, ('N075', 'R111', '23 ST'))
# (2108, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (2098, ('N325A', 'R218', 'ELMHURST AV'))
# (2097, ('R194', 'R040', '231 ST'))
# (2096, ('R174', 'R034', '125 ST'))
# (2083, ('R508', 'R346', 'COURT SQ'))
# (2055, ('N521', 'R300', '2 AV'))
# (2000, ('N124', 'R103', 'BROADWAY JCT'))
# (1993, ('A071', 'R044', 'CHAMBERS ST'))
# (1991, ('R504', 'R276', 'VERNON-JACKSON'))
# (1965, ('A014', 'R081', '49 ST'))
# (1958, ('C025', 'R215', '86 ST'))
# (1932, ('N510', 'R163', '14 ST'))
# (1906, ('A042', 'R086', 'PRINCE ST'))
# (1890, ('H022', 'R279', 'JEFFERSON ST'))
# (1883, ('H006', 'R330', '3 AV'))
# (1872, ('R311', 'R053', '3 AV-149 ST'))
# (1869, ('R514', 'R094', 'ASTORIA BLVD'))
# (1865, ('B024', 'R211', 'KINGS HWY'))
# (1862, ('R185', 'R274', '191 ST'))
# (1826, ('R600', 'R224', 'CLARK ST'))
# (1822, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1813, ('N025', 'R102', '125 ST'))
# (1805, ('R519', 'R223', '46 ST BLISS ST'))
# (1795, ('N529', 'R257', 'EAST BROADWAY'))
# (1791, ('R283', 'R221', '167 ST'))
# (1759, ('C019', 'R232', '45 ST'))
# (1738, ('R284', 'R243', '170 ST'))
# (1720, ('N128', 'R200', 'EUCLID AV'))
# (1714, ('N117', 'R198', 'NOSTRAND AV'))
# (1703, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (1696, ('N073', 'R013', '34 ST-PENN STA'))
# (1694, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1677, ('N217', 'R112', 'FORDHAM RD'))
# (1674, ('N343', 'R019', 'JAMAICA 179 ST'))
# (1661, ('R254', 'R181', '110 ST'))
# (1655, ('H013', 'R249', 'GRAHAM AV'))
# (1654, ('N013', 'R035', '168 ST'))
# (1626, ('N422', 'R318', 'FULTON ST'))
# (1621, ('H017', 'R265', 'MONTROSE AV'))
# (1608, ('R186', 'R036', 'DYCKMAN ST'))
# (1602, ('R420', 'R107', 'WESTCHESTER SQ'))
# (1597, ('B029', 'R172', 'BRIGHTON BEACH'))
# (1588, ('R245', 'R051', '59 ST'))
# (1568, ('N012', 'R035', '168 ST'))
# (1560, ('R530', 'R310', '111 ST'))
# (1557, ('N536', 'R270', 'SMITH-9 ST'))
# (1555, ('C021', 'R212', '59 ST'))
# (1527, ('R511', 'R091', '36 AV'))
# (1509, ('R188', 'R037', '207 ST'))
# (1508, ('N040', 'R251', '96 ST'))
# (1500, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1495, ('A064', 'R311', 'BOWERY'))
# (1471, ('B021', 'R228', 'AVENUE J'))
# (1462, ('R609', 'R056', 'NEVINS ST'))
# (1450, ('N546', 'R204', 'CHURCH AV'))
# (1440, ('H015', 'R250', 'GRAND ST'))
# (1422, ('B022', 'R229', 'AVENUE M'))
# (1418, ('N537', 'R258', '4 AV-9 ST'))
# (1415, ('R178', 'R273', '145 ST'))
# (1410, ('R139', 'R031', '34 ST-PENN STA'))
# (1410, ('N207', 'R104', '167 ST'))
# (1403, ('A039', 'R085', '8 ST-NYU'))
# (1390, ('N513', 'R163', '14 ST'))
# (1364, ('R135', 'R031', '34 ST-PENN STA'))
# (1358, ('A055', 'R227', 'RECTOR ST'))
# (1357, ('R294', 'R052', 'WOODLAWN'))
# (1345, ('H023', 'R236', 'DEKALB AV'))
# (1336, ('C022', 'R212', '59 ST'))
# (1333, ('N019', 'R101', '145 ST'))
# (1331, ('N314', 'R238', 'STEINWAY ST'))
# (1330, ('R517', 'R291', '33 ST-RAWSON ST'))
# (1291, ('R253', 'R181', '110 ST'))
# (1283, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (1274, ('R307', 'R207', '135 ST'))
# (1272, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1272, ('B023', 'R211', 'KINGS HWY'))
# (1248, ('C024', 'R214', '77 ST'))
# (1236, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (1234, ('R192', 'R039', 'MARBLE HILL-225'))
# (1226, ('R503', 'R276', 'VERNON-JACKSON'))
# (1219, ('R197', 'R117', 'V.CORTLANDT PK'))
# (1218, ('R286', 'R309', '176 ST'))
# (1217, ('N101', 'R252', 'HIGH ST'))
# (1203, ('N607', 'R025', 'JAMAICA CENTER'))
# (1198, ('R242A', 'R049', '51 ST'))
# (1196, ('R260', 'R205', '149/GRAND CONC'))
# (1158, ('N218', 'R112', 'FORDHAM RD'))
# (1152, ('R622', 'R123', 'FRANKLIN AV'))
# (1146, ('R285', 'R308', 'MT EDEN AV'))
# (1133, ('H028', 'R266', 'HALSEY ST'))
# (1130, ('N196', 'R285', 'FAR ROCKAWAY'))
# (1124, ('R510', 'R090', '39 AV'))
# (1116, ('B013', 'R196', 'PROSPECT PARK'))
# (1112, ('R605', 'R456', 'HOYT ST'))
# (1108, ('R629', 'R065', 'ROCKAWAY AV'))
# (1095, ('N549', 'R242', '18 AV'))
# (1092, ('N534', 'R220', 'CARROLL ST'))
# (1082, ('N339A', 'R114', 'PARSONS BLVD'))
# (1077, ('B018', 'R184', 'CORTELYOU RD'))
# (1070, ('B031', 'R172', 'BRIGHTON BEACH'))
# (1068, ('E004', 'R234', '50 ST'))
# (1060, ('N419', 'R287', 'CLASSON AV'))
# (1057, ('R418', 'R106', 'CASTLE HILL AV'))
# (1035, ('R520', 'R223', '46 ST BLISS ST'))
# (1034, ('E012', 'R372', '18 AV'))
# (1026, ('R634', 'R069', 'NEW LOTS AV'))
# (1026, ('N342', 'R019', 'JAMAICA 179 ST'))
# (1021, ('C010', 'R231', 'UNION ST'))
# (1006, ('R636', 'R209', 'STERLING ST'))
# (1006, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (998, ('C016', 'R278', '25 ST'))
# (987, ('R288', 'R275', '183 ST'))
# (986, ('R624', 'R124', 'KINGSTON AV'))
# (976, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (971, ('B017', 'R262', 'BEVERLEY ROAD'))
# (955, ('R628', 'R064', 'SARATOGA AV'))
# (955, ('R259', 'R307', '138/GRAND CONC'))
# (932, ('N340A', 'R115', '169 ST'))
# (923, ('N119', 'R199', 'KINGSTON-THROOP'))
# (922, ('B012', 'R196', 'PROSPECT PARK'))
# (915, ('N006A', 'R280', '190 ST'))
# (915, ('B015', 'R098', 'CHURCH AV'))
# (913, ('R623', 'R061', 'NOSTRAND AV'))
# (911, ('R130', 'R321', '18 ST'))
# (910, ('R525', 'R018', '74 ST-BROADWAY'))
# (903, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (902, ('C003', 'R089', 'JAY ST-METROTEC'))
# (899, ('N215', 'R237', '182-183 STS'))
# (890, ('N331', 'R219', '67 AV'))
# (883, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (836, ('C001', 'R108', 'BOROUGH HALL'))
# (828, ('C004', 'R089', 'JAY ST-METROTEC'))
# (825, ('N129', 'R382', 'GRANT AV'))
# (821, ('H032', 'R295', 'WILSON AV'))
# (795, ('H005', 'R330', '3 AV'))
# (788, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (782, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (761, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (757, ('R728', 'R226', 'GUN HILL RD'))
# (751, ('N330C', 'R202', '63 DR-REGO PARK'))
# (741, ('N334B', 'R341', '75 AV'))
# (738, ('E011', 'R371', '79 ST'))
# (737, ('R635', 'R277', 'PRESIDENT ST'))
# (718, ('E005', 'R247', '55 ST'))
# (716, ('E013', 'R373', '20 AV'))
# (711, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (710, ('R177', 'R273', '145 ST'))
# (703, ('N111', 'R284', 'CLINTON-WASH AV'))
# (702, ('R641', 'R210', 'BEVERLY RD'))
# (686, ('B024A', 'R211', 'KINGS HWY'))
# (682, ('N340', 'R115', '169 ST'))
# (682, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (671, ('R309', 'R345', 'HARLEM 148 ST'))
# (666, ('B026', 'R230', 'NECK RD'))
# (665, ('R308', 'R344', '145 ST'))
# (653, ('E009', 'R370', '71 ST'))
# (648, ('J035', 'R008', '111 ST'))
# (633, ('N210', 'R253', '174-175 STS'))
# (632, ('N337', 'R255', 'BRIARWOOD'))
# (629, ('S101', 'R070', 'ST. GEORGE'))
# (627, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (620, ('N212', 'R253', '174-175 STS'))
# (607, ('H016', 'R250', 'GRAND ST'))
# (581, ('N011', 'R126', '175 ST'))
# (580, ('K026', 'R100', 'METROPOLITAN AV'))
# (577, ('R126', 'R189', 'CHRISTOPHER ST'))
# (574, ('H035', 'R348', 'ATLANTIC AV'))
# (573, ('R506', 'R276', 'VERNON-JACKSON'))
# (570, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (570, ('B020', 'R263', 'AVENUE H'))
# (545, ('R190', 'R038', '215 ST'))
# (544, ('R416', 'R245', 'ST LAWRENCE AV'))
# (542, ('H014', 'R249', 'GRAHAM AV'))
# (542, ('B032', 'R264', 'OCEAN PKWY'))
# (506, ('C011', 'R231', 'UNION ST'))
# (485, ('R617', 'R058', 'BERGEN ST'))
# (485, ('C017', 'R455', '25 ST'))
# (484, ('N332', 'R219', '67 AV'))
# (483, ('R216', 'R322', 'SPRING ST'))
# (465, ('R633', 'R068', 'VAN SICLEN AV'))
# (463, ('N545', 'R204', 'CHURCH AV'))
# (458, ('N118', 'R199', 'KINGSTON-THROOP'))
# (449, ('J028', 'R004', '75 ST-ELDERTS'))
# (446, ('H003', 'R163', '6 AV'))
# (438, ('J030', 'R005', '85 ST-FOREST PK'))
# (425, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (420, ('N561', 'R271', 'AVENUE X'))
# (414, ('N191', 'R335', 'BEACH 67 ST'))
# (413, ('H033', 'R313', 'BUSHWICK AV'))
# (407, ('N206', 'R104', '167 ST'))
# (365, ('N192', 'R336', 'BEACH 60 ST'))
# (324, ('R413', 'R325', 'WHITLOCK AV'))
# (308, ('N556', 'R424', 'AVENUE P'))
# (299, ('R618', 'R058', 'BERGEN ST'))
# (295, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (274, ('N087', 'R282', 'SPRING ST'))
# (258, ('H030', 'R266', 'HALSEY ST'))
# (247, ('J037', 'R009', '121 ST'))
# (246, ('J025', 'R003', 'CYPRESS HILLS'))
# (241, ('N195', 'R358', 'BEACH 25 ST'))
# (241, ('C026', 'R215', '86 ST'))
# (207, ('B034', 'R264', 'OCEAN PKWY'))
# (193, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (186, ('J034', 'R007', '104 ST'))
# (161, ('N339', 'R114', 'PARSONS BLVD'))
# (133, ('N194', 'R338', 'BEACH 36 ST'))
# (130, ('N137', 'R354', '104 ST'))
# (105, ('N193', 'R337', 'BEACH 44 ST'))
# (2, ('R627', 'R063', 'SUTTER AV-RUTLD'))
# (0, ('R630', 'R066', 'JUNIUS ST'))
# (0, ('OB01', 'R459', 'ORCHARD BEACH'))
# (0, ('N550', 'R242', '18 AV'))

# %%
#Friday evening
friday = MTA[MTA.DATE == '06/16/2017']
friday = friday.reset_index(drop=True)

fri_evening=fri_evening=friday[(friday.TIME =="16:00:00")|(friday.TIME == "17:00:00")|(friday.TIME =="18:00:00")|(friday.TIME == "19:00:00")|(friday.TIME == "20:00:00")]
fri_evening = fri_evening.reset_index(drop=True)

fri_evening_dict={}
for i in range(len(fri_evening.index)):
    mytuple= (fri_evening['C/A'][i], fri_evening.UNIT[i], fri_evening.SCP[i], fri_evening.STATION[i])
    if mytuple not in fri_evening_dict.keys():
        fri_evening_dict[mytuple]={fri_evening.TIME[i]:fri_evening.ENTRIES[i]}
    else:
        fri_evening_dict[mytuple][fri_evening.TIME[i]]=fri_evening.ENTRIES[i]

bad_key = []
for key, value in fri_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in fri_evening_dict:
        del fri_evening_dict[key]

fri_evening_differences = {}
for turnstile,times in fri_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in fri_evening_differences:
        fri_evening_differences[mytuple]={turnstile[2]:count}
    else:
        fri_evening_differences[mytuple][turnstile[2]]=count

total_fri_evening_diff = {}
for key, value in fri_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_fri_evening_diff[key] = count
    
fri_evening_passengers = []
for key, value in total_fri_evening_diff.items():
    fri_evening_passengers.append((value, key))
fri_evening_passengers.sort(reverse=True)
for line in fri_evening_passengers:
    print(line)
# Out:
# (18945, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (15855, ('N500', 'R020', '47-50 STS ROCK'))
# (14754, ('N051', 'R084', '59 ST COLUMBUS'))
# (12459, ('N306', 'R017', 'LEXINGTON AV/53'))
# (11837, ('N501', 'R020', '47-50 STS ROCK'))
# (10451, ('N506', 'R022', '34 ST-HERALD SQ'))
# (10207, ('N505', 'R022', '34 ST-HERALD SQ'))
# (10188, ('R250', 'R179', '86 ST'))
# (9979, ('N520', 'R240', 'GRAND ST'))
# (9527, ('R533', 'R055', 'FLUSHING-MAIN'))
# (9432, ('N504', 'R021', '42 ST-BRYANT PK'))
# (8714, ('N103', 'R127', 'JAY ST-METROTEC'))
# (8634, ('R116', 'R030', 'CHAMBERS ST'))
# (8407, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (7744, ('N092', 'R029', 'CHAMBERS ST'))
# (7663, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (7636, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (7516, ('R200A', 'R041', 'BOWLING GREEN'))
# (7479, ('N502', 'R021', '42 ST-BRYANT PK'))
# (7415, ('A022', 'R022', '34 ST-HERALD SQ'))
# (7360, ('A010', 'R080', '57 ST-7 AV'))
# (7325, ('N094', 'R029', 'WORLD TRADE CTR'))
# (7075, ('H009', 'R235', 'BEDFORD AV'))
# (6766, ('R501', 'R054', '5 AVE'))
# (6658, ('N507', 'R023', '34 ST-HERALD SQ'))
# (6532, ('N049', 'R084', '59 ST COLUMBUS'))
# (6514, ('N026', 'R102', '125 ST'))
# (6430, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (6377, ('A002', 'R051', '59 ST'))
# (6346, ('R154', 'R116', '50 ST'))
# (6294, ('N089', 'R139', 'CANAL ST'))
# (6168, ('N509', 'R203', '23 ST'))
# (6116, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (6064, ('A030', 'R083', '23 ST'))
# (6032, ('C008', 'R099', 'DEKALB AV'))
# (6013, ('R244A', 'R050', '59 ST'))
# (5979, ('A025', 'R023', '34 ST-HERALD SQ'))
# (5976, ('N102', 'R127', 'JAY ST-METROTEC'))
# (5817, ('N606', 'R025', 'JAMAICA CENTER'))
# (5723, ('N091', 'R029', 'CHAMBERS ST'))
# (5721, ('R141', 'R031', '34 ST-PENN STA'))
# (5534, ('R217A', 'R194', 'BLEECKER ST'))
# (5512, ('R182', 'R035', '168 ST'))
# (5474, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (5459, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (5426, ('R602', 'R108', 'BOROUGH HALL'))
# (5406, ('R245A', 'R051', '59 ST'))
# (5404, ('R155', 'R116', '50 ST'))
# (5011, ('N501A', 'R020', '47-50 STS ROCK'))
# (4999, ('R242', 'R049', '51 ST'))
# (4945, ('A041', 'R086', 'PRINCE ST'))
# (4894, ('A015', 'R081', '49 ST'))
# (4868, ('R158', 'R084', '59 ST COLUMBUS'))
# (4852, ('N076', 'R111', '23 ST'))
# (4848, ('R249', 'R179', '86 ST'))
# (4786, ('R110', 'R027', 'WALL ST'))
# (4706, ('N072', 'R012', '34 ST-PENN STA'))
# (4695, ('N067', 'R012', '34 ST-PENN STA'))
# (4670, ('N503', 'R021', '42 ST-BRYANT PK'))
# (4646, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (4642, ('R111', 'R027', 'WALL ST'))
# (4605, ('R244', 'R050', '59 ST'))
# (4582, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (4441, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (4386, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (4380, ('S101A', 'R070', 'ST. GEORGE'))
# (4374, ('N057', 'R188', '50 ST'))
# (4275, ('N086', 'R282', 'SPRING ST'))
# (4251, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (4203, ('R243', 'R049', '51 ST'))
# (4171, ('R201', 'R041', 'BOWLING GREEN'))
# (4153, ('A011', 'R080', '57 ST-7 AV'))
# (4111, ('R127', 'R105', '14 ST'))
# (3947, ('A038', 'R085', '8 ST-NYU'))
# (3928, ('R526', 'R096', '82 ST-JACKSON H'))
# (3916, ('R550', 'R072', '34 ST-HUDSON YD'))
# (3897, ('N508', 'R453', '23 ST'))
# (3862, ('N108', 'R217', 'HOYT-SCHER'))
# (3833, ('N400A', 'R359', 'COURT SQ'))
# (3735, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3716, ('A031', 'R083', '23 ST'))
# (3707, ('N020', 'R101', '145 ST'))
# (3647, ('R215', 'R322', 'SPRING ST'))
# (3639, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (3615, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (3601, ('N305', 'R017', 'LEXINGTON AV/53'))
# (3581, ('R528', 'R097', 'JUNCTION BLVD'))
# (3531, ('N063', 'R011', '42 ST-PORT AUTH'))
# (3414, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (3365, ('N068', 'R012', '34 ST-PENN STA'))
# (3337, ('H007', 'R248', '1 AV'))
# (3282, ('A047', 'R087', 'CITY HALL'))
# (3276, ('N046', 'R281', '72 ST'))
# (3254, ('N090', 'R139', 'CANAL ST'))
# (3250, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (3167, ('N070', 'R012', '34 ST-PENN STA'))
# (3102, ('R527', 'R122', '90 ST-ELMHURST'))
# (3094, ('N043', 'R186', '86 ST'))
# (3089, ('N062', 'R011', '42 ST-PORT AUTH'))
# (3046, ('A027', 'R082', '28 ST'))
# (3038, ('N601', 'R319', 'LEXINGTON AV/63'))
# (3003, ('N523', 'R300', '2 AV'))
# (2963, ('R529', 'R208', '103 ST-CORONA'))
# (2954, ('R534', 'R055', 'FLUSHING-MAIN'))
# (2931, ('N307', 'R359', 'COURT SQ-23 ST'))
# (2919, ('R601A', 'R108', 'BOROUGH HALL'))
# (2857, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (2821, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (2816, ('C012', 'R258', '4AV-9 ST'))
# (2803, ('N056', 'R188', '50 ST'))
# (2782, ('R515', 'R095', 'ASTORIA DITMARS'))
# (2775, ('R183', 'R260', '181 ST'))
# (2750, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2734, ('R129', 'R321', '18 ST'))
# (2714, ('R516', 'R291', '33 ST-RAWSON ST'))
# (2634, ('N405', 'R239', 'GREENPOINT AV'))
# (2610, ('A013', 'R081', '49 ST'))
# (2575, ('R604', 'R108', 'BOROUGH HALL'))
# (2535, ('N528', 'R257', 'EAST BROADWAY'))
# (2526, ('R310', 'R053', '3 AV-149 ST'))
# (2510, ('R513', 'R093', '30 AV'))
# (2508, ('R306', 'R207', '135 ST'))
# (2404, ('R289', 'R119', 'FORDHAM RD'))
# (2391, ('N408A', 'R256', 'NASSAU AV'))
# (2379, ('N512', 'R163', '14 ST'))
# (2375, ('R125', 'R189', 'CHRISTOPHER ST'))
# (2361, ('R518', 'R261', '40 ST LOWERY ST'))
# (2353, ('N116', 'R198', 'NOSTRAND AV'))
# (2343, ('N511', 'R163', '14 ST'))
# (2315, ('A069', 'R044', 'CHAMBERS ST'))
# (2311, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (2300, ('R301', 'R323', 'CENTRAL PK N110'))
# (2288, ('R608', 'R056', 'NEVINS ST'))
# (2259, ('R512', 'R092', 'BROADWAY'))
# (2244, ('N010', 'R126', '175 ST'))
# (2239, ('R112', 'R027', 'WALL ST'))
# (2228, ('B016', 'R098', 'CHURCH AV'))
# (2225, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (2197, ('N069', 'R013', '34 ST-PENN STA'))
# (2190, ('R606', 'R225', 'HOYT ST'))
# (2180, ('A029', 'R082', '28 ST'))
# (2156, ('R103', 'R304', 'RECTOR ST'))
# (2144, ('R174', 'R034', '125 ST'))
# (2127, ('R112A', 'R027', 'WALL ST'))
# (2117, ('H019', 'R294', 'MORGAN AV'))
# (2101, ('C025', 'R215', '86 ST'))
# (2098, ('R261', 'R205', '149/GRAND CONC'))
# (2089, ('A016', 'R081', '49 ST'))
# (2083, ('N325A', 'R218', 'ELMHURST AV'))
# (2075, ('N077', 'R111', '23 ST'))
# (2073, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (2072, ('R519', 'R223', '46 ST BLISS ST'))
# (2061, ('R128', 'R105', '14 ST'))
# (2056, ('N521', 'R300', '2 AV'))
# (2045, ('R287', 'R244', 'BURNSIDE AV'))
# (2012, ('N100', 'R252', 'HIGH ST'))
# (2000, ('R514', 'R094', 'ASTORIA BLVD'))
# (1999, ('N039', 'R251', '96 ST'))
# (1998, ('R194', 'R040', '231 ST'))
# (1990, ('R504', 'R276', 'VERNON-JACKSON'))
# (1939, ('H022', 'R279', 'JEFFERSON ST'))
# (1935, ('R202', 'R042', 'BOWLING GREEN'))
# (1928, ('A054', 'R227', 'RECTOR ST'))
# (1901, ('N535', 'R220', 'CARROLL ST'))
# (1888, ('N071', 'R013', '34 ST-PENN STA'))
# (1845, ('B024', 'R211', 'KINGS HWY'))
# (1816, ('N124', 'R103', 'BROADWAY JCT'))
# (1770, ('H006', 'R330', '3 AV'))
# (1767, ('N025', 'R102', '125 ST'))
# (1765, ('R137', 'R031', '34 ST-PENN STA'))
# (1758, ('C019', 'R232', '45 ST'))
# (1757, ('N117', 'R198', 'NOSTRAND AV'))
# (1754, ('A014', 'R081', '49 ST'))
# (1752, ('N128', 'R200', 'EUCLID AV'))
# (1747, ('A042', 'R086', 'PRINCE ST'))
# (1740, ('R508', 'R346', 'COURT SQ'))
# (1740, ('R283', 'R221', '167 ST'))
# (1731, ('R115', 'R029', 'PARK PLACE'))
# (1730, ('A071', 'R044', 'CHAMBERS ST'))
# (1715, ('R102', 'R304', 'RECTOR ST'))
# (1712, ('R600', 'R224', 'CLARK ST'))
# (1710, ('H013', 'R249', 'GRAHAM AV'))
# (1708, ('R284', 'R243', '170 ST'))
# (1703, ('R311', 'R053', '3 AV-149 ST'))
# (1696, ('N012', 'R035', '168 ST'))
# (1689, ('R530', 'R310', '111 ST'))
# (1676, ('R511', 'R091', '36 AV'))
# (1665, ('N217', 'R112', 'FORDHAM RD'))
# (1662, ('N343', 'R019', 'JAMAICA 179 ST'))
# (1653, ('N075', 'R111', '23 ST'))
# (1644, ('N422', 'R318', 'FULTON ST'))
# (1638, ('N529', 'R257', 'EAST BROADWAY'))
# (1633, ('N087', 'R282', 'SPRING ST'))
# (1617, ('N510', 'R163', '14 ST'))
# (1615, ('R254', 'R181', '110 ST'))
# (1604, ('R245', 'R051', '59 ST'))
# (1599, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1598, ('H017', 'R265', 'MONTROSE AV'))
# (1577, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1560, ('R185', 'R274', '191 ST'))
# (1551, ('R188', 'R037', '207 ST'))
# (1537, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1535, ('N013', 'R035', '168 ST'))
# (1532, ('R420', 'R107', 'WESTCHESTER SQ'))
# (1515, ('R178', 'R273', '145 ST'))
# (1503, ('N073', 'R013', '34 ST-PENN STA'))
# (1502, ('R186', 'R036', 'DYCKMAN ST'))
# (1499, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (1475, ('C021', 'R212', '59 ST'))
# (1434, ('B029', 'R172', 'BRIGHTON BEACH'))
# (1400, ('N019', 'R101', '145 ST'))
# (1385, ('H023', 'R236', 'DEKALB AV'))
# (1374, ('A064', 'R311', 'BOWERY'))
# (1372, ('R294', 'R052', 'WOODLAWN'))
# (1365, ('N513', 'R163', '14 ST'))
# (1355, ('N207', 'R104', '167 ST'))
# (1354, ('R609', 'R056', 'NEVINS ST'))
# (1337, ('H015', 'R250', 'GRAND ST'))
# (1336, ('C022', 'R212', '59 ST'))
# (1329, ('N536', 'R270', 'SMITH-9 ST'))
# (1309, ('R139', 'R031', '34 ST-PENN STA'))
# (1309, ('N537', 'R258', '4 AV-9 ST'))
# (1300, ('A039', 'R085', '8 ST-NYU'))
# (1293, ('C024', 'R214', '77 ST'))
# (1289, ('R135', 'R031', '34 ST-PENN STA'))
# (1276, ('N546', 'R204', 'CHURCH AV'))
# (1270, ('R307', 'R207', '135 ST'))
# (1266, ('B022', 'R229', 'AVENUE M'))
# (1258, ('R253', 'R181', '110 ST'))
# (1253, ('N040', 'R251', '96 ST'))
# (1251, ('B013', 'R196', 'PROSPECT PARK'))
# (1249, ('R286', 'R309', '176 ST'))
# (1236, ('B021', 'R228', 'AVENUE J'))
# (1218, ('R197', 'R117', 'V.CORTLANDT PK'))
# (1209, ('R503', 'R276', 'VERNON-JACKSON'))
# (1202, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (1195, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1192, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (1182, ('N218', 'R112', 'FORDHAM RD'))
# (1175, ('N419', 'R287', 'CLASSON AV'))
# (1168, ('H028', 'R266', 'HALSEY ST'))
# (1163, ('A055', 'R227', 'RECTOR ST'))
# (1122, ('N196', 'R285', 'FAR ROCKAWAY'))
# (1104, ('R192', 'R039', 'MARBLE HILL-225'))
# (1097, ('N534', 'R220', 'CARROLL ST'))
# (1089, ('R285', 'R308', 'MT EDEN AV'))
# (1076, ('R622', 'R123', 'FRANKLIN AV'))
# (1065, ('B018', 'R184', 'CORTELYOU RD'))
# (1061, ('R605', 'R456', 'HOYT ST'))
# (1060, ('R636', 'R209', 'STERLING ST'))
# (1055, ('R418', 'R106', 'CASTLE HILL AV'))
# (1047, ('E012', 'R372', '18 AV'))
# (1040, ('B023', 'R211', 'KINGS HWY'))
# (1037, ('N607', 'R025', 'JAMAICA CENTER'))
# (1029, ('R288', 'R275', '183 ST'))
# (1028, ('R629', 'R065', 'ROCKAWAY AV'))
# (1025, ('R517', 'R291', '33 ST-RAWSON ST'))
# (1018, ('C010', 'R231', 'UNION ST'))
# (1007, ('R525', 'R018', '74 ST-BROADWAY'))
# (1004, ('R623', 'R061', 'NOSTRAND AV'))
# (982, ('R510', 'R090', '39 AV'))
# (976, ('B024A', 'R211', 'KINGS HWY'))
# (973, ('R520', 'R223', '46 ST BLISS ST'))
# (973, ('N340A', 'R115', '169 ST'))
# (971, ('R242A', 'R049', '51 ST'))
# (970, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (958, ('R634', 'R069', 'NEW LOTS AV'))
# (952, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (947, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (946, ('R624', 'R124', 'KINGSTON AV'))
# (944, ('R260', 'R205', '149/GRAND CONC'))
# (941, ('N342', 'R019', 'JAMAICA 179 ST'))
# (937, ('N339A', 'R114', 'PARSONS BLVD'))
# (936, ('N119', 'R199', 'KINGSTON-THROOP'))
# (936, ('N101', 'R252', 'HIGH ST'))
# (921, ('B012', 'R196', 'PROSPECT PARK'))
# (920, ('C016', 'R278', '25 ST'))
# (914, ('N549', 'R242', '18 AV'))
# (914, ('N006A', 'R280', '190 ST'))
# (901, ('R259', 'R307', '138/GRAND CONC'))
# (901, ('B015', 'R098', 'CHURCH AV'))
# (876, ('N215', 'R237', '182-183 STS'))
# (867, ('N129', 'R382', 'GRANT AV'))
# (858, ('B031', 'R172', 'BRIGHTON BEACH'))
# (853, ('E004', 'R234', '50 ST'))
# (843, ('R628', 'R064', 'SARATOGA AV'))
# (843, ('H032', 'R295', 'WILSON AV'))
# (833, ('H005', 'R330', '3 AV'))
# (832, ('R635', 'R277', 'PRESIDENT ST'))
# (799, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (786, ('E011', 'R371', '79 ST'))
# (784, ('C004', 'R089', 'JAY ST-METROTEC'))
# (764, ('E013', 'R373', '20 AV'))
# (748, ('R130', 'R321', '18 ST'))
# (741, ('C003', 'R089', 'JAY ST-METROTEC'))
# (737, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (724, ('R728', 'R226', 'GUN HILL RD'))
# (718, ('E009', 'R370', '71 ST'))
# (695, ('R309', 'R345', 'HARLEM 148 ST'))
# (690, ('R177', 'R273', '145 ST'))
# (681, ('N111', 'R284', 'CLINTON-WASH AV'))
# (676, ('R308', 'R344', '145 ST'))
# (675, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (673, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (666, ('S101', 'R070', 'ST. GEORGE'))
# (665, ('C001', 'R108', 'BOROUGH HALL'))
# (662, ('N334B', 'R341', '75 AV'))
# (657, ('B026', 'R230', 'NECK RD'))
# (651, ('N011', 'R126', '175 ST'))
# (645, ('R641', 'R210', 'BEVERLY RD'))
# (644, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (637, ('N337', 'R255', 'BRIARWOOD'))
# (637, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (632, ('N340', 'R115', '169 ST'))
# (614, ('N212', 'R253', '174-175 STS'))
# (604, ('K026', 'R100', 'METROPOLITAN AV'))
# (602, ('N210', 'R253', '174-175 STS'))
# (596, ('B017', 'R262', 'BEVERLEY ROAD'))
# (592, ('H014', 'R249', 'GRAHAM AV'))
# (584, ('R216', 'R322', 'SPRING ST'))
# (546, ('E005', 'R247', '55 ST'))
# (541, ('J035', 'R008', '111 ST'))
# (540, ('R126', 'R189', 'CHRISTOPHER ST'))
# (535, ('R416', 'R245', 'ST LAWRENCE AV'))
# (532, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (526, ('R506', 'R276', 'VERNON-JACKSON'))
# (518, ('H016', 'R250', 'GRAND ST'))
# (513, ('B020', 'R263', 'AVENUE H'))
# (510, ('R617', 'R058', 'BERGEN ST'))
# (502, ('J030', 'R005', '85 ST-FOREST PK'))
# (491, ('H035', 'R348', 'ATLANTIC AV'))
# (484, ('C011', 'R231', 'UNION ST'))
# (470, ('R190', 'R038', '215 ST'))
# (466, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (462, ('N545', 'R204', 'CHURCH AV'))
# (452, ('N118', 'R199', 'KINGSTON-THROOP'))
# (451, ('C017', 'R455', '25 ST'))
# (436, ('J028', 'R004', '75 ST-ELDERTS'))
# (433, ('R633', 'R068', 'VAN SICLEN AV'))
# (425, ('N206', 'R104', '167 ST'))
# (418, ('B032', 'R264', 'OCEAN PKWY'))
# (407, ('N561', 'R271', 'AVENUE X'))
# (396, ('H033', 'R313', 'BUSHWICK AV'))
# (392, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (385, ('N191', 'R335', 'BEACH 67 ST'))
# (367, ('H003', 'R163', '6 AV'))
# (366, ('N192', 'R336', 'BEACH 60 ST'))
# (313, ('R413', 'R325', 'WHITLOCK AV'))
# (313, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (280, ('R618', 'R058', 'BERGEN ST'))
# (276, ('N556', 'R424', 'AVENUE P'))
# (251, ('N195', 'R358', 'BEACH 25 ST'))
# (241, ('J025', 'R003', 'CYPRESS HILLS'))
# (224, ('J037', 'R009', '121 ST'))
# (219, ('H030', 'R266', 'HALSEY ST'))
# (215, ('C026', 'R215', '86 ST'))
# (170, ('B034', 'R264', 'OCEAN PKWY'))
# (169, ('N339', 'R114', 'PARSONS BLVD'))
# (151, ('J034', 'R007', '104 ST'))
# (148, ('N194', 'R338', 'BEACH 36 ST'))
# (143, ('N137', 'R354', '104 ST'))
# (135, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (110, ('N193', 'R337', 'BEACH 44 ST'))
# (20, ('OB01', 'R459', 'ORCHARD BEACH'))
# (0, ('R630', 'R066', 'JUNIUS ST'))
# (0, ('R627', 'R063', 'SUTTER AV-RUTLD'))
# (0, ('N550', 'R242', '18 AV'))

# %%
#Saturday evening

saturday = MTA[MTA.DATE == '06/10/2017']
saturday = saturday.reset_index(drop=True)

sat_evening=sat_evening=saturday[(saturday.TIME =="16:00:00")|(saturday.TIME == "17:00:00")|(saturday.TIME =="18:00:00")|(saturday.TIME == "19:00:00")|(saturday.TIME == "20:00:00")]
sat_evening = sat_evening.reset_index(drop=True)

sat_evening_dict={}
for i in range(len(sat_evening.index)):
    mytuple= (sat_evening['C/A'][i], sat_evening.UNIT[i], sat_evening.SCP[i], sat_evening.STATION[i])
    if mytuple not in sat_evening_dict.keys():
        sat_evening_dict[mytuple]={sat_evening.TIME[i]:sat_evening.ENTRIES[i]}
    else:
        sat_evening_dict[mytuple][sat_evening.TIME[i]]=sat_evening.ENTRIES[i]

bad_key = []
for key, value in sat_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in sat_evening_dict:
        del sat_evening_dict[key]

sat_evening_differences = {}
for turnstile,times in sat_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in sat_evening_differences:
        sat_evening_differences[mytuple]={turnstile[2]:count}
    else:
        sat_evening_differences[mytuple][turnstile[2]]=count

total_sat_evening_diff = {}
for key, value in sat_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_sat_evening_diff[key] = count
    
sat_evening_passengers = []
for key, value in total_sat_evening_diff.items():
    sat_evening_passengers.append((value, key))
sat_evening_passengers.sort(reverse=True)
for line in sat_evening_passengers:
    print(line)
# Out:
# (11762, ('H009', 'R235', 'BEDFORD AV'))
# (10404, ('N506', 'R022', '34 ST-HERALD SQ'))
# (9099, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (7437, ('R533', 'R055', 'FLUSHING-MAIN'))
# (6818, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (6775, ('N051', 'R084', '59 ST COLUMBUS'))
# (6059, ('N049', 'R084', '59 ST COLUMBUS'))
# (6015, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (5942, ('N520', 'R240', 'GRAND ST'))
# (5522, ('R250', 'R179', '86 ST'))
# (4960, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (4919, ('N026', 'R102', '125 ST'))
# (4758, ('A010', 'R080', '57 ST-7 AV'))
# (4122, ('N103', 'R127', 'JAY ST-METROTEC'))
# (4045, ('N094', 'R029', 'WORLD TRADE CTR'))
# (4013, ('A041', 'R086', 'PRINCE ST'))
# (3973, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3956, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (3859, ('A022', 'R022', '34 ST-HERALD SQ'))
# (3659, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (3617, ('N606', 'R025', 'JAMAICA CENTER'))
# (3558, ('R127', 'R105', '14 ST'))
# (3498, ('R249', 'R179', '86 ST'))
# (3484, ('R116', 'R030', 'CHAMBERS ST'))
# (3460, ('A030', 'R083', '23 ST'))
# (3454, ('R141', 'R031', '34 ST-PENN STA'))
# (3428, ('N500', 'R020', '47-50 STS ROCK'))
# (3393, ('N076', 'R111', '23 ST'))
# (3286, ('N067', 'R012', '34 ST-PENN STA'))
# (3239, ('N072', 'R012', '34 ST-PENN STA'))
# (3215, ('C008', 'R099', 'DEKALB AV'))
# (3147, ('R526', 'R096', '82 ST-JACKSON H'))
# (3141, ('R158', 'R084', '59 ST COLUMBUS'))
# (3111, ('R528', 'R097', 'JUNCTION BLVD'))
# (3087, ('R217A', 'R194', 'BLEECKER ST'))
# (3024, ('N505', 'R022', '34 ST-HERALD SQ'))
# (2948, ('N507', 'R023', '34 ST-HERALD SQ'))
# (2945, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (2848, ('A038', 'R085', '8 ST-NYU'))
# (2832, ('N092', 'R029', 'CHAMBERS ST'))
# (2770, ('N020', 'R101', '145 ST'))
# (2758, ('R215', 'R322', 'SPRING ST'))
# (2708, ('A002', 'R051', '59 ST'))
# (2684, ('N509', 'R203', '23 ST'))
# (2603, ('A031', 'R083', '23 ST'))
# (2550, ('N046', 'R281', '72 ST'))
# (2545, ('N057', 'R188', '50 ST'))
# (2536, ('R527', 'R122', '90 ST-ELMHURST'))
# (2522, ('R529', 'R208', '103 ST-CORONA'))
# (2486, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (2443, ('A025', 'R023', '34 ST-HERALD SQ'))
# (2409, ('H008', 'R248', '1 AV'))
# (2407, ('R512', 'R092', 'BROADWAY'))
# (2403, ('N306', 'R017', 'LEXINGTON AV/53'))
# (2382, ('R183', 'R260', '181 ST'))
# (2341, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (2326, ('R534', 'R055', 'FLUSHING-MAIN'))
# (2301, ('R600', 'R224', 'CLARK ST'))
# (2289, ('N089', 'R139', 'CANAL ST'))
# (2283, ('R155', 'R116', '50 ST'))
# (2230, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (2180, ('R254', 'R181', '110 ST'))
# (2165, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2156, ('R501', 'R054', '5 AVE'))
# (2131, ('R301', 'R323', 'CENTRAL PK N110'))
# (2118, ('N108', 'R217', 'HOYT-SCHER'))
# (2104, ('N501', 'R020', '47-50 STS ROCK'))
# (2096, ('R515', 'R095', 'ASTORIA DITMARS'))
# (2095, ('R128', 'R105', '14 ST'))
# (2090, ('R245A', 'R051', '59 ST'))
# (2080, ('N523', 'R300', '2 AV'))
# (2075, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (2048, ('N062', 'R011', '42 ST-PORT AUTH'))
# (2030, ('R253', 'R181', '110 ST'))
# (2024, ('R513', 'R093', '30 AV'))
# (2022, ('N502', 'R021', '42 ST-BRYANT PK'))
# (2013, ('H007', 'R248', '1 AV'))
# (2003, ('N504', 'R021', '42 ST-BRYANT PK'))
# (1996, ('N116', 'R198', 'NOSTRAND AV'))
# (1990, ('R550', 'R072', '34 ST-HUDSON YD'))
# (1969, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (1959, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (1946, ('R289', 'R119', 'FORDHAM RD'))
# (1931, ('R244', 'R050', '59 ST'))
# (1903, ('R514', 'R094', 'ASTORIA BLVD'))
# (1900, ('B016', 'R098', 'CHURCH AV'))
# (1894, ('A015', 'R081', '49 ST'))
# (1893, ('R244A', 'R050', '59 ST'))
# (1861, ('R306', 'R207', '135 ST'))
# (1836, ('N503', 'R021', '42 ST-BRYANT PK'))
# (1822, ('C012', 'R258', '4AV-9 ST'))
# (1801, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (1758, ('N056', 'R188', '50 ST'))
# (1751, ('A011', 'R080', '57 ST-7 AV'))
# (1746, ('N528', 'R257', 'EAST BROADWAY'))
# (1719, ('H019', 'R294', 'MORGAN AV'))
# (1715, ('N043', 'R186', '86 ST'))
# (1710, ('R111', 'R027', 'WALL ST'))
# (1695, ('N063', 'R011', '42 ST-PORT AUTH'))
# (1670, ('N086', 'R282', 'SPRING ST'))
# (1667, ('N070', 'R012', '34 ST-PENN STA'))
# (1665, ('R174', 'R034', '125 ST'))
# (1653, ('A054', 'R227', 'RECTOR ST'))
# (1644, ('R530', 'R310', '111 ST'))
# (1630, ('R504', 'R276', 'VERNON-JACKSON'))
# (1625, ('R178', 'R273', '145 ST'))
# (1623, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (1622, ('R182', 'R035', '168 ST'))
# (1612, ('N400A', 'R359', 'COURT SQ'))
# (1611, ('N601', 'R319', 'LEXINGTON AV/63'))
# (1588, ('N077', 'R111', '23 ST'))
# (1565, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1562, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (1552, ('N521', 'R300', '2 AV'))
# (1526, ('R110', 'R027', 'WALL ST'))
# (1521, ('H017', 'R265', 'MONTROSE AV'))
# (1516, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (1512, ('R194', 'R040', '231 ST'))
# (1497, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1490, ('R186', 'R036', 'DYCKMAN ST'))
# (1486, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (1481, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (1475, ('R601A', 'R108', 'BOROUGH HALL'))
# (1467, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (1454, ('N330', 'R202', '63 DR-REGO PARK'))
# (1453, ('R519', 'R223', '46 ST BLISS ST'))
# (1441, ('C025', 'R215', '86 ST'))
# (1426, ('B013', 'R196', 'PROSPECT PARK'))
# (1411, ('A042', 'R086', 'PRINCE ST'))
# (1409, ('N124', 'R103', 'BROADWAY JCT'))
# (1400, ('A027', 'R082', '28 ST'))
# (1395, ('R242', 'R049', '51 ST'))
# (1395, ('R154', 'R116', '50 ST'))
# (1385, ('H013', 'R249', 'GRAHAM AV'))
# (1383, ('N010', 'R126', '175 ST'))
# (1380, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1380, ('R188', 'R037', '207 ST'))
# (1377, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1364, ('B029', 'R172', 'BRIGHTON BEACH'))
# (1362, ('R287', 'R244', 'BURNSIDE AV'))
# (1353, ('H022', 'R279', 'JEFFERSON ST'))
# (1344, ('R283', 'R221', '167 ST'))
# (1339, ('R294', 'R052', 'WOODLAWN'))
# (1319, ('R310', 'R053', '3 AV-149 ST'))
# (1312, ('N128', 'R200', 'EUCLID AV'))
# (1308, ('R243', 'R049', '51 ST'))
# (1288, ('N512', 'R163', '14 ST'))
# (1276, ('N315', 'R238', 'STEINWAY ST'))
# (1264, ('R185', 'R274', '191 ST'))
# (1254, ('R606', 'R225', 'HOYT ST'))
# (1247, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (1244, ('A039', 'R085', '8 ST-NYU'))
# (1241, ('A064', 'R311', 'BOWERY'))
# (1238, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (1231, ('R508', 'R346', 'COURT SQ'))
# (1227, ('N217', 'R112', 'FORDHAM RD'))
# (1217, ('R602', 'R108', 'BOROUGH HALL'))
# (1201, ('N019', 'R101', '145 ST'))
# (1191, ('N071', 'R013', '34 ST-PENN STA'))
# (1190, ('H006', 'R330', '3 AV'))
# (1184, ('N102', 'R127', 'JAY ST-METROTEC'))
# (1178, ('N343', 'R019', 'JAMAICA 179 ST'))
# (1178, ('A047', 'R087', 'CITY HALL'))
# (1161, ('B024', 'R211', 'KINGS HWY'))
# (1158, ('N535', 'R220', 'CARROLL ST'))
# (1157, ('N529', 'R257', 'EAST BROADWAY'))
# (1146, ('B031', 'R172', 'BRIGHTON BEACH'))
# (1145, ('R511', 'R091', '36 AV'))
# (1142, ('A016', 'R081', '49 ST'))
# (1141, ('N025', 'R102', '125 ST'))
# (1130, ('R518', 'R261', '40 ST LOWERY ST'))
# (1129, ('N307', 'R359', 'COURT SQ-23 ST'))
# (1126, ('N012', 'R035', '168 ST'))
# (1122, ('N537', 'R258', '4 AV-9 ST'))
# (1110, ('H023', 'R236', 'DEKALB AV'))
# (1102, ('R103', 'R304', 'RECTOR ST'))
# (1096, ('N207', 'R104', '167 ST'))
# (1096, ('A013', 'R081', '49 ST'))
# (1094, ('H028', 'R266', 'HALSEY ST'))
# (1067, ('N117', 'R198', 'NOSTRAND AV'))
# (1063, ('R284', 'R243', '170 ST'))
# (1044, ('B012', 'R196', 'PROSPECT PARK'))
# (1037, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (1032, ('R197', 'R117', 'V.CORTLANDT PK'))
# (1024, ('N068', 'R012', '34 ST-PENN STA'))
# (1004, ('N422', 'R318', 'FULTON ST'))
# (1000, ('R261', 'R205', '149/GRAND CONC'))
# (985, ('R311', 'R053', '3 AV-149 ST'))
# (984, ('B018', 'R184', 'CORTELYOU RD'))
# (974, ('R608', 'R056', 'NEVINS ST'))
# (973, ('H015', 'R250', 'GRAND ST'))
# (969, ('C022', 'R212', '59 ST'))
# (938, ('A029', 'R082', '28 ST'))
# (935, ('C021', 'R212', '59 ST'))
# (934, ('A014', 'R081', '49 ST'))
# (926, ('R245', 'R051', '59 ST'))
# (926, ('C024', 'R214', '77 ST'))
# (924, ('R192', 'R039', 'MARBLE HILL-225'))
# (910, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (908, ('N546', 'R204', 'CHURCH AV'))
# (893, ('N536', 'R270', 'SMITH-9 ST'))
# (876, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (869, ('N006A', 'R280', '190 ST'))
# (855, ('N501A', 'R020', '47-50 STS ROCK'))
# (835, ('R418', 'R106', 'CASTLE HILL AV'))
# (830, ('N069', 'R013', '34 ST-PENN STA'))
# (818, ('R525', 'R018', '74 ST-BROADWAY'))
# (811, ('N039', 'R251', '96 ST'))
# (808, ('B015', 'R098', 'CHURCH AV'))
# (803, ('S101A', 'R070', 'ST. GEORGE'))
# (799, ('N218', 'R112', 'FORDHAM RD'))
# (791, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (787, ('R503', 'R276', 'VERNON-JACKSON'))
# (785, ('R286', 'R309', '176 ST'))
# (781, ('R285', 'R308', 'MT EDEN AV'))
# (781, ('N090', 'R139', 'CANAL ST'))
# (776, ('B021', 'R228', 'AVENUE J'))
# (773, ('N215', 'R237', '182-183 STS'))
# (771, ('N325A', 'R218', 'ELMHURST AV'))
# (770, ('R420', 'R107', 'WESTCHESTER SQ'))
# (769, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (765, ('N534', 'R220', 'CARROLL ST'))
# (760, ('R288', 'R275', '183 ST'))
# (756, ('N073', 'R013', '34 ST-PENN STA'))
# (753, ('N129', 'R382', 'GRANT AV'))
# (747, ('N191', 'R335', 'BEACH 67 ST'))
# (745, ('C019', 'R232', '45 ST'))
# (743, ('R135', 'R031', '34 ST-PENN STA'))
# (734, ('N013', 'R035', '168 ST'))
# (730, ('R126', 'R189', 'CHRISTOPHER ST'))
# (730, ('E012', 'R372', '18 AV'))
# (725, ('N314', 'R238', 'STEINWAY ST'))
# (716, ('R636', 'R209', 'STERLING ST'))
# (714, ('N196', 'R285', 'FAR ROCKAWAY'))
# (708, ('N419', 'R287', 'CLASSON AV'))
# (704, ('R307', 'R207', '135 ST'))
# (703, ('N119', 'R199', 'KINGSTON-THROOP'))
# (701, ('R622', 'R123', 'FRANKLIN AV'))
# (693, ('N040', 'R251', '96 ST'))
# (689, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (673, ('H032', 'R295', 'WILSON AV'))
# (668, ('N340A', 'R115', '169 ST'))
# (662, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (660, ('R510', 'R090', '39 AV'))
# (644, ('R623', 'R061', 'NOSTRAND AV'))
# (643, ('R260', 'R205', '149/GRAND CONC'))
# (638, ('B024A', 'R211', 'KINGS HWY'))
# (632, ('R139', 'R031', '34 ST-PENN STA'))
# (626, ('N342', 'R019', 'JAMAICA 179 ST'))
# (624, ('N513', 'R163', '14 ST'))
# (620, ('R605', 'R456', 'HOYT ST'))
# (619, ('R115', 'R029', 'PARK PLACE'))
# (612, ('B022', 'R229', 'AVENUE M'))
# (610, ('A069', 'R044', 'CHAMBERS ST'))
# (609, ('R617', 'R058', 'BERGEN ST'))
# (609, ('N339A', 'R114', 'PARSONS BLVD'))
# (608, ('N305', 'R017', 'LEXINGTON AV/53'))
# (599, ('R308', 'R344', '145 ST'))
# (596, ('B023', 'R211', 'KINGS HWY'))
# (591, ('N510', 'R163', '14 ST'))
# (591, ('N075', 'R111', '23 ST'))
# (588, ('R604', 'R108', 'BOROUGH HALL'))
# (587, ('C001', 'R108', 'BOROUGH HALL'))
# (579, ('R516', 'R291', '33 ST-RAWSON ST'))
# (571, ('R520', 'R223', '46 ST BLISS ST'))
# (565, ('E011', 'R371', '79 ST'))
# (564, ('R177', 'R273', '145 ST'))
# (554, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (536, ('B032', 'R264', 'OCEAN PKWY'))
# (526, ('B026', 'R230', 'NECK RD'))
# (524, ('E009', 'R370', '71 ST'))
# (523, ('R102', 'R304', 'RECTOR ST'))
# (523, ('E013', 'R373', '20 AV'))
# (519, ('R609', 'R056', 'NEVINS ST'))
# (516, ('R416', 'R245', 'ST LAWRENCE AV'))
# (513, ('S101', 'R070', 'ST. GEORGE'))
# (512, ('H005', 'R330', '3 AV'))
# (502, ('R624', 'R124', 'KINGSTON AV'))
# (497, ('R309', 'R345', 'HARLEM 148 ST'))
# (494, ('C017', 'R455', '25 ST'))
# (492, ('R641', 'R210', 'BEVERLY RD'))
# (478, ('B017', 'R262', 'BEVERLEY ROAD'))
# (470, ('R635', 'R277', 'PRESIDENT ST'))
# (456, ('N340', 'R115', '169 ST'))
# (445, ('K026', 'R100', 'METROPOLITAN AV'))
# (436, ('N210', 'R253', '174-175 STS'))
# (433, ('R130', 'R321', '18 ST'))
# (431, ('A055', 'R227', 'RECTOR ST'))
# (424, ('N011', 'R126', '175 ST'))
# (418, ('C011', 'R231', 'UNION ST'))
# (417, ('R506', 'R276', 'VERNON-JACKSON'))
# (417, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (416, ('N549', 'R242', '18 AV'))
# (416, ('N331', 'R219', '67 AV'))
# (409, ('J030', 'R005', '85 ST-FOREST PK'))
# (408, ('N111', 'R284', 'CLINTON-WASH AV'))
# (402, ('R259', 'R307', '138/GRAND CONC'))
# (393, ('R728', 'R226', 'GUN HILL RD'))
# (388, ('N607', 'R025', 'JAMAICA CENTER'))
# (388, ('N545', 'R204', 'CHURCH AV'))
# (387, ('H014', 'R249', 'GRAHAM AV'))
# (386, ('H033', 'R313', 'BUSHWICK AV'))
# (381, ('H016', 'R250', 'GRAND ST'))
# (368, ('J035', 'R008', '111 ST'))
# (365, ('N087', 'R282', 'SPRING ST'))
# (355, ('N192', 'R336', 'BEACH 60 ST'))
# (355, ('B020', 'R263', 'AVENUE H'))
# (352, ('R190', 'R038', '215 ST'))
# (350, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (342, ('J028', 'R004', '75 ST-ELDERTS'))
# (339, ('R216', 'R322', 'SPRING ST'))
# (339, ('N212', 'R253', '174-175 STS'))
# (332, ('N511', 'R163', '14 ST'))
# (332, ('N337', 'R255', 'BRIARWOOD'))
# (316, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (309, ('A071', 'R044', 'CHAMBERS ST'))
# (304, ('N330C', 'R202', '63 DR-REGO PARK'))
# (294, ('H035', 'R348', 'ATLANTIC AV'))
# (285, ('E004', 'R234', '50 ST'))
# (283, ('N206', 'R104', '167 ST'))
# (268, ('N561', 'R271', 'AVENUE X'))
# (251, ('C003', 'R089', 'JAY ST-METROTEC'))
# (247, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (239, ('C004', 'R089', 'JAY ST-METROTEC'))
# (231, ('R413', 'R325', 'WHITLOCK AV'))
# (227, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (219, ('N118', 'R199', 'KINGSTON-THROOP'))
# (215, ('R618', 'R058', 'BERGEN ST'))
# (208, ('N332', 'R219', '67 AV'))
# (199, ('N195', 'R358', 'BEACH 25 ST'))
# (192, ('H003', 'R163', '6 AV'))
# (184, ('N556', 'R424', 'AVENUE P'))
# (183, ('N334B', 'R341', '75 AV'))
# (179, ('R517', 'R291', '33 ST-RAWSON ST'))
# (165, ('C026', 'R215', '86 ST'))
# (164, ('E005', 'R247', '55 ST'))
# (157, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (156, ('H030', 'R266', 'HALSEY ST'))
# (147, ('J025', 'R003', 'CYPRESS HILLS'))
# (127, ('N339', 'R114', 'PARSONS BLVD'))
# (122, ('J037', 'R009', '121 ST'))
# (121, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (118, ('J034', 'R007', '104 ST'))
# (115, ('B034', 'R264', 'OCEAN PKWY'))
# (112, ('N194', 'R338', 'BEACH 36 ST'))
# (105, ('N137', 'R354', '104 ST'))
# (81, ('N193', 'R337', 'BEACH 44 ST'))
# (4, ('R201', 'R041', 'BOWLING GREEN'))
# (1, ('R125', 'R189', 'CHRISTOPHER ST'))
# (1, ('N408A', 'R256', 'NASSAU AV'))
# (1, ('N101', 'R252', 'HIGH ST'))
# (1, ('C016', 'R278', '25 ST'))
# (0, ('R634', 'R069', 'NEW LOTS AV'))
# (0, ('R633', 'R068', 'VAN SICLEN AV'))
# (0, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (0, ('R629', 'R065', 'ROCKAWAY AV'))
# (0, ('R628', 'R064', 'SARATOGA AV'))
# (0, ('R242A', 'R049', '51 ST'))
# (0, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (0, ('R202', 'R042', 'BOWLING GREEN'))
# (0, ('R200A', 'R041', 'BOWLING GREEN'))
# (0, ('R137', 'R031', '34 ST-PENN STA'))
# (0, ('R129', 'R321', '18 ST'))
# (0, ('R112A', 'R027', 'WALL ST'))
# (0, ('R112', 'R027', 'WALL ST'))
# (0, ('OB01', 'R459', 'ORCHARD BEACH'))
# (0, ('N550', 'R242', '18 AV'))
# (0, ('N508', 'R453', '23 ST'))
# (0, ('N405', 'R239', 'GREENPOINT AV'))
# (0, ('N100', 'R252', 'HIGH ST'))
# (0, ('N091', 'R029', 'CHAMBERS ST'))
# (0, ('C010', 'R231', 'UNION ST'))

# %%
#Sunday evening

sunday = MTA[MTA.DATE == '06/11/2017']
sunday = sunday.reset_index(drop=True)

sun_evening=sun_evening=sunday[(sunday.TIME =="16:00:00")|(sunday.TIME == "17:00:00")|(sunday.TIME =="18:00:00")|(sunday.TIME == "19:00:00")|(sunday.TIME == "20:00:00")]
sun_evening = sun_evening.reset_index(drop=True)

sun_evening_dict={}
for i in range(len(sun_evening.index)):
    mytuple= (sun_evening['C/A'][i], sun_evening.UNIT[i], sun_evening.SCP[i], sun_evening.STATION[i])
    if mytuple not in sun_evening_dict.keys():
        sun_evening_dict[mytuple]={sun_evening.TIME[i]:sun_evening.ENTRIES[i]}
    else:
        sun_evening_dict[mytuple][sun_evening.TIME[i]]=sun_evening.ENTRIES[i]

bad_key = []
for key, value in sun_evening_dict.items():
    if len(value) != 2:
        bad_key.append(key)
for key in bad_key:
    if key in sun_evening_dict:
        del sun_evening_dict[key]

sun_evening_differences = {}
for turnstile,times in sun_evening_dict.items():
    mytuple = (turnstile[0], turnstile[1], turnstile[3])
    count = 0
    for time, entry in times.items():
        count = entry - count
    if mytuple not in sun_evening_differences:
        sun_evening_differences[mytuple]={turnstile[2]:count}
    else:
        sun_evening_differences[mytuple][turnstile[2]]=count

total_sun_evening_diff = {}
for key, value in sun_evening_differences.items():
    count = 0
    for key2, value2 in value.items():
        count += value2
    total_sun_evening_diff[key] = count
    
sun_evening_passengers = []
for key, value in total_sun_evening_diff.items():
    sun_evening_passengers.append((value, key))
sun_evening_passengers.sort(reverse=True)
for line in sun_evening_passengers:
    print(line)
# Out:
# (8361, ('R238', 'R046', 'GRD CNTRL-42 ST'))
# (7774, ('H009', 'R235', 'BEDFORD AV'))
# (6913, ('N506', 'R022', '34 ST-HERALD SQ'))
# (6263, ('R533', 'R055', 'FLUSHING-MAIN'))
# (5858, ('R151', 'R033', 'TIMES SQ-42 ST'))
# (5540, ('N051', 'R084', '59 ST COLUMBUS'))
# (5314, ('N520', 'R240', 'GRAND ST'))
# (5277, ('N324', 'R018', 'JKSN HT-ROOSVLT'))
# (5036, ('R250', 'R179', '86 ST'))
# (4996, ('N049', 'R084', '59 ST COLUMBUS'))
# (4504, ('R147', 'R033', 'TIMES SQ-42 ST'))
# (4126, ('A010', 'R080', '57 ST-7 AV'))
# (4093, ('N067', 'R012', '34 ST-PENN STA'))
# (4024, ('N026', 'R102', '125 ST'))
# (3543, ('N072', 'R012', '34 ST-PENN STA'))
# (3370, ('N605', 'R024', 'SUTPHIN-ARCHER'))
# (3284, ('R626', 'R062', 'CROWN HTS-UTICA'))
# (3258, ('R610', 'R057', 'ATL AV-BARCLAY'))
# (3090, ('N103', 'R127', 'JAY ST-METROTEC'))
# (2962, ('A041', 'R086', 'PRINCE ST'))
# (2918, ('A022', 'R022', '34 ST-HERALD SQ'))
# (2846, ('R249', 'R179', '86 ST'))
# (2829, ('R158', 'R084', '59 ST COLUMBUS'))
# (2770, ('R612', 'R057', 'ATL AV-BARCLAY'))
# (2765, ('R141', 'R031', '34 ST-PENN STA'))
# (2710, ('A030', 'R083', '23 ST'))
# (2602, ('R116', 'R030', 'CHAMBERS ST'))
# (2573, ('N606', 'R025', 'JAMAICA CENTER'))
# (2520, ('C009', 'R057', 'ATL AV-BARCLAY'))
# (2494, ('R217A', 'R194', 'BLEECKER ST'))
# (2472, ('R526', 'R096', '82 ST-JACKSON H'))
# (2449, ('A025', 'R023', '34 ST-HERALD SQ'))
# (2447, ('N505', 'R022', '34 ST-HERALD SQ'))
# (2435, ('R528', 'R097', 'JUNCTION BLVD'))
# (2430, ('N046', 'R281', '72 ST'))
# (2400, ('N062', 'R011', '42 ST-PORT AUTH'))
# (2382, ('C008', 'R099', 'DEKALB AV'))
# (2361, ('N057', 'R188', '50 ST'))
# (2353, ('B031', 'R172', 'BRIGHTON BEACH'))
# (2344, ('N094', 'R029', 'WORLD TRADE CTR'))
# (2338, ('R127', 'R105', '14 ST'))
# (2256, ('G011', 'R312', 'W 8 ST-AQUARIUM'))
# (2247, ('B029', 'R172', 'BRIGHTON BEACH'))
# (2179, ('R155', 'R116', '50 ST'))
# (2178, ('B013', 'R196', 'PROSPECT PARK'))
# (2156, ('N500', 'R020', '47-50 STS ROCK'))
# (2129, ('A002', 'R051', '59 ST'))
# (2124, ('A038', 'R085', '8 ST-NYU'))
# (2120, ('N076', 'R111', '23 ST'))
# (2107, ('N507', 'R023', '34 ST-HERALD SQ'))
# (2068, ('N020', 'R101', '145 ST'))
# (2063, ('R215', 'R322', 'SPRING ST'))
# (2046, ('R148', 'R033', 'TIMES SQ-42 ST'))
# (2041, ('R527', 'R122', '90 ST-ELMHURST'))
# (1975, ('R529', 'R208', '103 ST-CORONA'))
# (1944, ('A031', 'R083', '23 ST'))
# (1896, ('N089', 'R139', 'CANAL ST'))
# (1891, ('H008', 'R248', '1 AV'))
# (1878, ('N323', 'R018', 'JKSN HT-ROOSVLT'))
# (1867, ('N509', 'R203', '23 ST'))
# (1833, ('N063A', 'R011', '42 ST-PORT AUTH'))
# (1820, ('N422', 'R318', 'FULTON ST'))
# (1816, ('N191', 'R335', 'BEACH 67 ST'))
# (1805, ('R501', 'R054', '5 AVE'))
# (1780, ('R183', 'R260', '181 ST'))
# (1747, ('R244A', 'R050', '59 ST'))
# (1744, ('R534', 'R055', 'FLUSHING-MAIN'))
# (1729, ('N523', 'R300', '2 AV'))
# (1715, ('A011', 'R080', '57 ST-7 AV'))
# (1710, ('N501', 'R020', '47-50 STS ROCK'))
# (1678, ('A015', 'R081', '49 ST'))
# (1656, ('N306', 'R017', 'LEXINGTON AV/53'))
# (1645, ('R244', 'R050', '59 ST'))
# (1643, ('R512', 'R092', 'BROADWAY'))
# (1640, ('R245A', 'R051', '59 ST'))
# (1636, ('R550', 'R072', '34 ST-HUDSON YD'))
# (1632, ('N063', 'R011', '42 ST-PORT AUTH'))
# (1627, ('H007', 'R248', '1 AV'))
# (1621, ('R423', 'R429', 'PELHAM BAY PARK'))
# (1598, ('R509', 'R121', 'QUEENSBORO PLZ'))
# (1589, ('R125', 'R189', 'CHRISTOPHER ST'))
# (1584, ('R515', 'R095', 'ASTORIA DITMARS'))
# (1581, ('N043', 'R186', '86 ST'))
# (1546, ('R514', 'R094', 'ASTORIA BLVD'))
# (1536, ('N502', 'R021', '42 ST-BRYANT PK'))
# (1533, ('N528', 'R257', 'EAST BROADWAY'))
# (1522, ('B016', 'R098', 'CHURCH AV'))
# (1515, ('H026', 'R137', 'MYRTLE-WYCKOFF'))
# (1514, ('N070', 'R012', '34 ST-PENN STA'))
# (1513, ('N116', 'R198', 'NOSTRAND AV'))
# (1500, ('R289', 'R119', 'FORDHAM RD'))
# (1497, ('N108', 'R217', 'HOYT-SCHER'))
# (1497, ('N056', 'R188', '50 ST'))
# (1455, ('N503', 'R021', '42 ST-BRYANT PK'))
# (1445, ('R210', 'R044', 'BROOKLYN BRIDGE'))
# (1431, ('N504', 'R021', '42 ST-BRYANT PK'))
# (1428, ('R301', 'R323', 'CENTRAL PK N110'))
# (1399, ('N092', 'R029', 'CHAMBERS ST'))
# (1392, ('N100', 'R252', 'HIGH ST'))
# (1372, ('R513', 'R093', '30 AV'))
# (1370, ('R306', 'R207', '135 ST'))
# (1369, ('R621', 'R060', 'EASTN PKWY-MUSM'))
# (1349, ('R238A', 'R046', 'GRD CNTRL-42 ST'))
# (1342, ('N501A', 'R020', '47-50 STS ROCK'))
# (1329, ('N071', 'R013', '34 ST-PENN STA'))
# (1321, ('R619', 'R059', 'GRAND ARMY PLAZ'))
# (1314, ('R530', 'R310', '111 ST'))
# (1285, ('N417', 'R269', 'BEDFORD-NOSTRAN'))
# (1275, ('R194', 'R040', '231 ST'))
# (1269, ('N521', 'R300', '2 AV'))
# (1264, ('H019', 'R294', 'MORGAN AV'))
# (1252, ('A021', 'R032', 'TIMES SQ-42 ST'))
# (1247, ('R504', 'R276', 'VERNON-JACKSON'))
# (1212, ('R128', 'R105', '14 ST'))
# (1208, ('R242', 'R049', '51 ST'))
# (1208, ('N330', 'R202', '63 DR-REGO PARK'))
# (1204, ('N086', 'R282', 'SPRING ST'))
# (1195, ('R182', 'R035', '168 ST'))
# (1182, ('N602', 'R259', 'ROOSEVELT ISLND'))
# (1175, ('N010', 'R126', '175 ST'))
# (1173, ('N601', 'R319', 'LEXINGTON AV/63'))
# (1171, ('R174', 'R034', '125 ST'))
# (1165, ('R143', 'R032', 'TIMES SQ-42 ST'))
# (1163, ('R200A', 'R041', 'BOWLING GREEN'))
# (1158, ('N603', 'R303', '21 ST-QNSBRIDGE'))
# (1152, ('N124', 'R103', 'BROADWAY JCT'))
# (1146, ('R154', 'R116', '50 ST'))
# (1145, ('R600', 'R224', 'CLARK ST'))
# (1145, ('H017', 'R265', 'MONTROSE AV'))
# (1138, ('R519', 'R223', '46 ST BLISS ST'))
# (1132, ('R110', 'R027', 'WALL ST'))
# (1127, ('R178', 'R273', '145 ST'))
# (1123, ('A064', 'R311', 'BOWERY'))
# (1090, ('R186', 'R036', 'DYCKMAN ST'))
# (1089, ('A042', 'R086', 'PRINCE ST'))
# (1086, ('C012', 'R258', '4AV-9 ST'))
# (1083, ('A016', 'R081', '49 ST'))
# (1067, ('R145', 'R032', 'TIMES SQ-42 ST'))
# (1063, ('N091', 'R029', 'CHAMBERS ST'))
# (1061, ('N077', 'R111', '23 ST'))
# (1059, ('N601A', 'R319', 'LEXINGTON AV/63'))
# (1054, ('H022', 'R279', 'JEFFERSON ST'))
# (1054, ('C025', 'R215', '86 ST'))
# (1048, ('N128', 'R200', 'EUCLID AV'))
# (1044, ('R310', 'R053', '3 AV-149 ST'))
# (1044, ('A027', 'R082', '28 ST'))
# (1039, ('A013', 'R081', '49 ST'))
# (1028, ('R243', 'R049', '51 ST'))
# (1021, ('R518', 'R261', '40 ST LOWERY ST'))
# (1021, ('H027', 'R137', 'MYRTLE-WYCKOFF'))
# (1020, ('R287', 'R244', 'BURNSIDE AV'))
# (1019, ('R185', 'R274', '191 ST'))
# (1018, ('R602', 'R108', 'BOROUGH HALL'))
# (1012, ('R111', 'R027', 'WALL ST'))
# (1011, ('R283', 'R221', '167 ST'))
# (987, ('B012', 'R196', 'PROSPECT PARK'))
# (981, ('B024', 'R211', 'KINGS HWY'))
# (973, ('N400A', 'R359', 'COURT SQ'))
# (973, ('H023', 'R236', 'DEKALB AV'))
# (972, ('R188', 'R037', '207 ST'))
# (940, ('B021', 'R228', 'AVENUE J'))
# (939, ('R202', 'R042', 'BOWLING GREEN'))
# (926, ('B032', 'R264', 'OCEAN PKWY'))
# (921, ('R284', 'R243', '170 ST'))
# (918, ('R135', 'R031', '34 ST-PENN STA'))
# (917, ('N217', 'R112', 'FORDHAM RD'))
# (913, ('R601A', 'R108', 'BOROUGH HALL'))
# (907, ('H013', 'R249', 'GRAHAM AV'))
# (899, ('H006', 'R330', '3 AV'))
# (897, ('A014', 'R081', '49 ST'))
# (890, ('R508', 'R346', 'COURT SQ'))
# (890, ('R254', 'R181', '110 ST'))
# (883, ('N117', 'R198', 'NOSTRAND AV'))
# (869, ('R606', 'R225', 'HOYT ST'))
# (857, ('A039', 'R085', '8 ST-NYU'))
# (853, ('N025', 'R102', '125 ST'))
# (843, ('N315', 'R238', 'STEINWAY ST'))
# (838, ('N327', 'R254', 'GRAND-NEWTOWN'))
# (835, ('N207', 'R104', '167 ST'))
# (832, ('N512', 'R163', '14 ST'))
# (825, ('H028', 'R266', 'HALSEY ST'))
# (823, ('R294', 'R052', 'WOODLAWN'))
# (823, ('N529', 'R257', 'EAST BROADWAY'))
# (816, ('N019', 'R101', '145 ST'))
# (813, ('N343', 'R019', 'JAMAICA 179 ST'))
# (811, ('R604', 'R108', 'BOROUGH HALL'))
# (804, ('C021', 'R212', '59 ST'))
# (803, ('R511', 'R091', '36 AV'))
# (802, ('R197', 'R117', 'V.CORTLANDT PK'))
# (799, ('R261', 'R205', '149/GRAND CONC'))
# (789, ('R192', 'R039', 'MARBLE HILL-225'))
# (786, ('R129', 'R321', '18 ST'))
# (785, ('A047', 'R087', 'CITY HALL'))
# (784, ('N535', 'R220', 'CARROLL ST'))
# (765, ('R139', 'R031', '34 ST-PENN STA'))
# (755, ('N307', 'R359', 'COURT SQ-23 ST'))
# (745, ('C022', 'R212', '59 ST'))
# (739, ('B018', 'R184', 'CORTELYOU RD'))
# (738, ('N102', 'R127', 'JAY ST-METROTEC'))
# (731, ('R503', 'R276', 'VERNON-JACKSON'))
# (723, ('N546', 'R204', 'CHURCH AV'))
# (722, ('N073', 'R013', '34 ST-PENN STA'))
# (717, ('R525', 'R018', '74 ST-BROADWAY'))
# (716, ('N537', 'R258', '4 AV-9 ST'))
# (713, ('N181A', 'R464', 'AQUEDUCT RACETR'))
# (709, ('A029', 'R082', '28 ST'))
# (704, ('N012', 'R035', '168 ST'))
# (702, ('N006A', 'R280', '190 ST'))
# (699, ('R103', 'R304', 'RECTOR ST'))
# (699, ('N068', 'R012', '34 ST-PENN STA'))
# (691, ('C019', 'R232', '45 ST'))
# (685, ('N090', 'R139', 'CANAL ST'))
# (682, ('B022', 'R229', 'AVENUE M'))
# (678, ('N039', 'R251', '96 ST'))
# (676, ('R245', 'R051', '59 ST'))
# (676, ('A054', 'R227', 'RECTOR ST'))
# (666, ('E012', 'R372', '18 AV'))
# (650, ('R311', 'R053', '3 AV-149 ST'))
# (650, ('N325A', 'R218', 'ELMHURST AV'))
# (645, ('R415', 'R120', 'MORISN AV/SNDVW'))
# (641, ('N536', 'R270', 'SMITH-9 ST'))
# (639, ('C024', 'R214', '77 ST'))
# (635, ('R608', 'R056', 'NEVINS ST'))
# (628, ('R636', 'R209', 'STERLING ST'))
# (625, ('B015', 'R098', 'CHURCH AV'))
# (613, ('R286', 'R309', '176 ST'))
# (613, ('N218', 'R112', 'FORDHAM RD'))
# (612, ('N196', 'R285', 'FAR ROCKAWAY'))
# (602, ('R418', 'R106', 'CASTLE HILL AV'))
# (602, ('R288', 'R275', '183 ST'))
# (599, ('N141', 'R356', 'OZONE PK LEFFRT'))
# (589, ('R625', 'R062', 'CROWN HTS-UTICA'))
# (577, ('H015', 'R250', 'GRAND ST'))
# (572, ('N314', 'R238', 'STEINWAY ST'))
# (568, ('R260', 'R205', '149/GRAND CONC'))
# (565, ('N129', 'R382', 'GRANT AV'))
# (563, ('R201', 'R041', 'BOWLING GREEN'))
# (562, ('N119', 'R199', 'KINGSTON-THROOP'))
# (558, ('B023', 'R211', 'KINGS HWY'))
# (555, ('R624', 'R124', 'KINGSTON AV'))
# (553, ('N013', 'R035', '168 ST'))
# (551, ('R253', 'R181', '110 ST'))
# (549, ('N040', 'R251', '96 ST'))
# (548, ('R307', 'R207', '135 ST'))
# (539, ('N069', 'R013', '34 ST-PENN STA'))
# (532, ('H032', 'R295', 'WILSON AV'))
# (528, ('R516', 'R291', '33 ST-RAWSON ST'))
# (515, ('N549', 'R242', '18 AV'))
# (511, ('E013', 'R373', '20 AV'))
# (507, ('R285', 'R308', 'MT EDEN AV'))
# (503, ('N419', 'R287', 'CLASSON AV'))
# (502, ('R291', 'R183', 'BEDFORD PK BLVD'))
# (500, ('R622', 'R123', 'FRANKLIN AV'))
# (496, ('R520', 'R223', '46 ST BLISS ST'))
# (496, ('R420', 'R107', 'WESTCHESTER SQ'))
# (496, ('N305A', 'R016', 'LEXINGTON AV/53'))
# (495, ('S101A', 'R070', 'ST. GEORGE'))
# (494, ('N534', 'R220', 'CARROLL ST'))
# (493, ('N215', 'R237', '182-183 STS'))
# (488, ('E004', 'R234', '50 ST'))
# (482, ('A069', 'R044', 'CHAMBERS ST'))
# (480, ('R623', 'R061', 'NOSTRAND AV'))
# (478, ('N340A', 'R115', '169 ST'))
# (470, ('R177', 'R273', '145 ST'))
# (462, ('N339A', 'R114', 'PARSONS BLVD'))
# (457, ('H003', 'R163', '6 AV'))
# (450, ('N075', 'R111', '23 ST'))
# (448, ('R510', 'R090', '39 AV'))
# (446, ('R126', 'R189', 'CHRISTOPHER ST'))
# (446, ('N510', 'R163', '14 ST'))
# (444, ('R605', 'R456', 'HOYT ST'))
# (439, ('R609', 'R056', 'NEVINS ST'))
# (439, ('B024A', 'R211', 'KINGS HWY'))
# (438, ('E009', 'R370', '71 ST'))
# (437, ('N342', 'R019', 'JAMAICA 179 ST'))
# (428, ('R416', 'R245', 'ST LAWRENCE AV'))
# (419, ('J031', 'R006', 'WOODHAVEN BLVD'))
# (418, ('E011', 'R371', '79 ST'))
# (416, ('R309', 'R345', 'HARLEM 148 ST'))
# (415, ('R617', 'R058', 'BERGEN ST'))
# (407, ('N513', 'R163', '14 ST'))
# (393, ('R115', 'R029', 'PARK PLACE'))
# (393, ('H005', 'R330', '3 AV'))
# (389, ('N192', 'R336', 'BEACH 60 ST'))
# (382, ('B026', 'R230', 'NECK RD'))
# (376, ('B017', 'R262', 'BEVERLEY ROAD'))
# (373, ('N418', 'R269', 'BEDFORD-NOSTRAN'))
# (373, ('N087', 'R282', 'SPRING ST'))
# (371, ('N011', 'R126', '175 ST'))
# (370, ('R308', 'R344', '145 ST'))
# (370, ('B020', 'R263', 'AVENUE H'))
# (368, ('R641', 'R210', 'BEVERLY RD'))
# (363, ('K026', 'R100', 'METROPOLITAN AV'))
# (362, ('C017', 'R455', '25 ST'))
# (355, ('C001', 'R108', 'BOROUGH HALL'))
# (353, ('C011', 'R231', 'UNION ST'))
# (348, ('N210', 'R253', '174-175 STS'))
# (345, ('N607', 'R025', 'JAMAICA CENTER'))
# (341, ('R635', 'R277', 'PRESIDENT ST'))
# (333, ('J035', 'R008', '111 ST'))
# (330, ('N340', 'R115', '169 ST'))
# (326, ('N305', 'R017', 'LEXINGTON AV/53'))
# (317, ('J030', 'R005', '85 ST-FOREST PK'))
# (313, ('E005', 'R247', '55 ST'))
# (311, ('C027', 'R216', 'BAY RIDGE-95 ST'))
# (310, ('N101', 'R252', 'HIGH ST'))
# (310, ('H014', 'R249', 'GRAHAM AV'))
# (306, ('N561', 'R271', 'AVENUE X'))
# (303, ('R506', 'R276', 'VERNON-JACKSON'))
# (289, ('N545', 'R204', 'CHURCH AV'))
# (288, ('R728', 'R226', 'GUN HILL RD'))
# (288, ('H016', 'R250', 'GRAND ST'))
# (278, ('S101', 'R070', 'ST. GEORGE'))
# (276, ('R102', 'R304', 'RECTOR ST'))
# (275, ('N331', 'R219', '67 AV'))
# (263, ('R259', 'R307', '138/GRAND CONC'))
# (259, ('J028', 'R004', '75 ST-ELDERTS'))
# (259, ('H033', 'R313', 'BUSHWICK AV'))
# (252, ('R216', 'R322', 'SPRING ST'))
# (238, ('R130', 'R321', '18 ST'))
# (237, ('N511', 'R163', '14 ST'))
# (234, ('N330C', 'R202', '63 DR-REGO PARK'))
# (233, ('R190', 'R038', '215 ST'))
# (233, ('A055', 'R227', 'RECTOR ST'))
# (232, ('N212', 'R253', '174-175 STS'))
# (230, ('H035', 'R348', 'ATLANTIC AV'))
# (222, ('N112A', 'R284', 'CLINTON-WASH AV'))
# (219, ('N111', 'R284', 'CLINTON-WASH AV'))
# (211, ('N337', 'R255', 'BRIARWOOD'))
# (202, ('N118', 'R199', 'KINGSTON-THROOP'))
# (202, ('A071', 'R044', 'CHAMBERS ST'))
# (196, ('N206', 'R104', '167 ST'))
# (192, ('N556', 'R424', 'AVENUE P'))
# (191, ('C028', 'R216', 'BAY RIDGE-95 ST'))
# (176, ('C004', 'R089', 'JAY ST-METROTEC'))
# (174, ('N334B', 'R341', '75 AV'))
# (169, ('N195', 'R358', 'BEACH 25 ST'))
# (168, ('R413', 'R325', 'WHITLOCK AV'))
# (164, ('C003', 'R089', 'JAY ST-METROTEC'))
# (159, ('R210A', 'R044', 'BROOKLYN BRIDGE'))
# (159, ('N194', 'R338', 'BEACH 36 ST'))
# (151, ('R618', 'R058', 'BERGEN ST'))
# (150, ('R517', 'R291', '33 ST-RAWSON ST'))
# (144, ('N332', 'R219', '67 AV'))
# (141, ('G015', 'R312', 'W 8 ST-AQUARIUM'))
# (139, ('J032', 'R006', 'WOODHAVEN BLVD'))
# (127, ('H030', 'R266', 'HALSEY ST'))
# (126, ('J034', 'R007', '104 ST'))
# (116, ('B034', 'R264', 'OCEAN PKWY'))
# (113, ('C026', 'R215', '86 ST'))
# (112, ('N339', 'R114', 'PARSONS BLVD'))
# (101, ('J025', 'R003', 'CYPRESS HILLS'))
# (90, ('J037', 'R009', '121 ST'))
# (78, ('N137', 'R354', '104 ST'))
# (57, ('N193', 'R337', 'BEACH 44 ST'))
# (3, ('OB01', 'R459', 'ORCHARD BEACH'))
# (1, ('N508', 'R453', '23 ST'))
# (0, ('R634', 'R069', 'NEW LOTS AV'))
# (0, ('R633', 'R068', 'VAN SICLEN AV'))
# (0, ('R632', 'R067', 'PENNSYLVANIA AV'))
# (0, ('R629', 'R065', 'ROCKAWAY AV'))
# (0, ('R628', 'R064', 'SARATOGA AV'))
# (0, ('R242A', 'R049', '51 ST'))
# (0, ('R237', 'R046', 'GRD CNTRL-42 ST'))
# (0, ('R137', 'R031', '34 ST-PENN STA'))
# (0, ('R112A', 'R027', 'WALL ST'))
# (0, ('R112', 'R027', 'WALL ST'))
# (0, ('N550', 'R242', '18 AV'))
# (0, ('N408A', 'R256', 'NASSAU AV'))
# (0, ('N405', 'R239', 'GREENPOINT AV'))
# (0, ('C016', 'R278', '25 ST'))
# (0, ('C010', 'R231', 'UNION ST'))
